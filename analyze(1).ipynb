# %%
import pandas as pd
import streamlit as st
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('games-data.csv')
df
# Out:
#                       ResponseName  ReleaseDate  Metacritic  \
# 0                   Counter-Strike   Nov 1 2000          88
# 1            Team Fortress Classic   Apr 1 1999           0
# 2                    Day of Defeat   May 1 2003          79
# 3               Deathmatch Classic   Jun 1 2001           0
# 4        Half-Life: Opposing Force   Nov 1 1999           0
# ...                            ...          ...         ...
# 12619                 ObserVR Beta  Oct 26 2016           0
# 12620              One Night Stand          NaN           0
# 12621  Fiber Twig: Midnight Puzzle  Oct 26 2016           0
# 12622             Charm Tale Quest  Oct 27 2016           0
# 12623          What The Heck Dude?   Nov 2 2016           0
#
#        RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 0                    68991   False           False         False
# 1                     2439   False           False         False
# 2                     2319   False           False         False
# 3                      888   False           False         False
# 4                     2934   False           False         False
# ...                    ...     ...             ...           ...
# 12619                    0    True            True         False
# 12620                    0   False           False          True
# 12621                    0   False           False          True
# 12622                    0   False           False          True
# 12623                    0   False           False          True
#
#        GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 0               True             False          False            False
# 1               True             False          False            False
# 2               True             False          False            False
# 3               True             False          False            False
# 4               True             False          False            False
# ...              ...               ...            ...              ...
# 12619          False             False          False            False
# 12620          False             False           True            False
# 12621          False             False           True            False
# 12622          False             False           True            False
# 12623           True             False           True            False
#
#        GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 0           False              False               False              False
# 1           False              False               False              False
# 2           False              False               False              False
# 3           False              False               False              False
# 4           False              False               False              False
# ...           ...                ...                 ...                ...
# 12619       False              False                True              False
# 12620       False               True               False              False
# 12621       False              False               False              False
# 12622       False              False               False              False
# 12623       False               True                True              False
#
#        GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial
# 0              False          False                        False          9.99
# 1              False          False                        False          4.99
# 2              False          False                        False          4.99
# 3              False          False                        False          4.99
# 4              False          False                        False          4.99
# ...              ...            ...                          ...           ...
# 12619          False          False                        False          0.00
# 12620          False          False                        False          0.00
# 12621          False          False                        False          2.99
# 12622          False          False                        False          2.99
# 12623          False          False                        False          0.00
#
# [12624 rows x 19 columns]

# %%
df = df.sort_values(by='RecommendationCount',ascending=False)
df = df.iloc[:5000]
df
# Out:
#                           ResponseName  ReleaseDate  Metacritic  \
# 27    Counter-Strike: Global Offensive  Aug 21 2012          83
# 23                              Dota 2   Jul 9 2013          90
# 20                     Team Fortress 2  Oct 10 2007          92
# 150                         Garrys Mod  Nov 29 2006           0
# 4028                          Unturned   Jul 7 2014           0
# ...                                ...          ...         ...
# 9907                          Event[0]  Sep 14 2016          84
# 9001      The Treasures of Montezuma 5  Mar 10 2016           0
# 9002                       Tokyo Babel  Mar 31 2016           0
# 9900                        Just Bones   Jun 9 2016           0
# 9908                         The Tribe  Aug 26 2016           0
#
#       RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 27                1427633   False           False         False
# 23                 590480    True           False         False
# 20                 383949    True           False         False
# 150                237684   False           False          True
# 4028               222301    True           False          True
# ...                   ...     ...             ...           ...
# 9907                    0   False           False          True
# 9001                    0   False           False         False
# 9002                    0   False           False         False
# 9900                    0   False           False          True
# 9908                    0   False           False          True
#
#       GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 27             True             False          False            False
# 23             True             False          False             True
# 20             True             False          False            False
# 150           False             False          False            False
# 4028           True              True           True            False
# ...             ...               ...            ...              ...
# 9907          False              True          False            False
# 9001          False             False           True            False
# 9002          False              True          False            False
# 9900          False             False          False            False
# 9908           True              True          False            False
#
#       GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 27         False              False               False              False
# 23         False              False               False               True
# 20         False              False               False               True
# 150        False               True               False              False
# 4028       False              False                True               True
# ...          ...                ...                 ...                ...
# 9907       False              False               False              False
# 9001       False              False               False              False
# 9002       False              False               False              False
# 9900       False              False               False              False
# 9908       False              False               False              False
#
#       GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial
# 27            False          False                        False         14.99
# 23            False          False                        False          0.00
# 20            False          False                        False          0.00
# 150           False          False                        False          9.99
# 4028          False          False                        False          0.00
# ...             ...            ...                          ...           ...
# 9907          False          False                        False         19.99
# 9001          False          False                        False          6.99
# 9002          False          False                        False         34.99
# 9900          False          False                        False          4.99
# 9908          False          False                        False          4.99
#
# [5000 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# ResponseName                    0
# ReleaseDate                    17
# Metacritic                      0
# RecommendationCount             0
# IsFree                          0
# GenreIsNonGame                  0
# GenreIsIndie                    0
# GenreIsAction                   0
# GenreIsAdventure                0
# GenreIsCasual                   0
# GenreIsStrategy                 0
# GenreIsRPG                      0
# GenreIsSimulation               0
# GenreIsEarlyAccess              0
# GenreIsFreeToPlay               0
# GenreIsSports                   0
# GenreIsRacing                   0
# GenreIsMassivelyMultiplayer     0
# PriceInitial                    0
# dtype: int64

# %%
sns.set(rc={'figure.figsize':(19.7, 8.27)})
sns.heatmap(
  df.isnull(),
  yticklabels=False,
  cbar=False,
  cmap='viridis'
)

plt.show()

# %%
df.dropna(inplace=True)
# 96  1427633

# %%
df['score'] = ((df.Metacritic/96)*0.5 + (df.RecommendationCount/1427633)*0.5)*1000
df
# Out:
#                           ResponseName  ReleaseDate  Metacritic  \
# 27    Counter-Strike: Global Offensive  Aug 21 2012          83
# 23                              Dota 2   Jul 9 2013          90
# 20                     Team Fortress 2  Oct 10 2007          92
# 150                         Garrys Mod  Nov 29 2006           0
# 4028                          Unturned   Jul 7 2014           0
# ...                                ...          ...         ...
# 9907                          Event[0]  Sep 14 2016          84
# 9001      The Treasures of Montezuma 5  Mar 10 2016           0
# 9002                       Tokyo Babel  Mar 31 2016           0
# 9900                        Just Bones   Jun 9 2016           0
# 9908                         The Tribe  Aug 26 2016           0
#
#       RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 27                1427633   False           False         False
# 23                 590480    True           False         False
# 20                 383949    True           False         False
# 150                237684   False           False          True
# 4028               222301    True           False          True
# ...                   ...     ...             ...           ...
# 9907                    0   False           False          True
# 9001                    0   False           False         False
# 9002                    0   False           False         False
# 9900                    0   False           False          True
# 9908                    0   False           False          True
#
#       GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 27             True             False          False            False
# 23             True             False          False             True
# 20             True             False          False            False
# 150           False             False          False            False
# 4028           True              True           True            False
# ...             ...               ...            ...              ...
# 9907          False              True          False            False
# 9001          False             False           True            False
# 9002          False              True          False            False
# 9900          False             False          False            False
# 9908           True              True          False            False
#
#       GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 27         False              False               False              False
# 23         False              False               False               True
# 20         False              False               False               True
# 150        False               True               False              False
# 4028       False              False                True               True
# ...          ...                ...                 ...                ...
# 9907       False              False               False              False
# 9001       False              False               False              False
# 9002       False              False               False              False
# 9900       False              False               False              False
# 9908       False              False               False              False
#
#       GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial  \
# 27            False          False                        False         14.99
# 23            False          False                        False          0.00
# 20            False          False                        False          0.00
# 150           False          False                        False          9.99
# 4028          False          False                        False          0.00
# ...             ...            ...                          ...           ...
# 9907          False          False                        False         19.99
# 9001          False          False                        False          6.99
# 9002          False          False                        False         34.99
# 9900          False          False                        False          4.99
# 9908          False          False                        False          4.99
#
#            score
# 27    932.291667
# 23    675.553849
# 20    613.637150
# 150    83.244083
# 4028   77.856494
# ...          ...
# 9907  437.500000
# 9001    0.000000
# 9002    0.000000
# 9900    0.000000
# 9908    0.000000
#
# [4983 rows x 20 columns]

# %%
df = df.sort_values(by='score',ascending=False)

# %%
df
# Out:
#                           ResponseName  ReleaseDate  Metacritic  \
# 27    Counter-Strike: Global Offensive  Aug 21 2012          83
# 23                              Dota 2   Jul 9 2013          90
# 20                     Team Fortress 2  Oct 10 2007          92
# 1365       The Elder Scrolls V: Skyrim  Nov 10 2011          94
# 3088                Grand Theft Auto V  Apr 13 2015          96
# ...                                ...          ...         ...
# 9030                            Bonsai  Feb 18 2016           0
# 8948                         Spellbind   Mar 4 2016           0
# 9932                       Galaxy Golf  Aug 24 2016           0
# 8525                        Nordenfelt  Jan 14 2016           0
# 9908                         The Tribe  Aug 26 2016           0
#
#       RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 27                1427633   False           False         False
# 23                 590480    True           False         False
# 20                 383949    True           False         False
# 1365               182587   False           False         False
# 3088               136846   False           False         False
# ...                   ...     ...             ...           ...
# 9030                    0   False           False          True
# 8948                    0   False           False          True
# 9932                    0   False           False          True
# 8525                    0   False           False          True
# 9908                    0   False           False          True
#
#       GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 27             True             False          False            False
# 23             True             False          False             True
# 20             True             False          False            False
# 1365          False             False          False            False
# 3088           True              True          False            False
# ...             ...               ...            ...              ...
# 9030          False             False           True            False
# 8948          False              True           True            False
# 9932          False             False           True            False
# 8525           True             False          False            False
# 9908           True              True          False            False
#
#       GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 27         False              False               False              False
# 23         False              False               False               True
# 20         False              False               False               True
# 1365        True              False               False              False
# 3088       False              False               False              False
# ...          ...                ...                 ...                ...
# 9030       False               True               False              False
# 8948       False              False               False              False
# 9932       False              False               False              False
# 8525       False              False               False              False
# 9908       False              False               False              False
#
#       GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial  \
# 27            False          False                        False         14.99
# 23            False          False                        False          0.00
# 20            False          False                        False          0.00
# 1365          False          False                        False         19.99
# 3088          False          False                        False         59.99
# ...             ...            ...                          ...           ...
# 9030          False          False                        False          0.99
# 8948          False          False                        False          2.99
# 9932           True          False                        False          4.99
# 8525          False          False                        False          8.99
# 9908          False          False                        False          4.99
#
#            score
# 27    932.291667
# 23    675.553849
# 20    613.637150
# 1365  553.530790
# 3088  547.927584
# ...          ...
# 9030    0.000000
# 8948    0.000000
# 9932    0.000000
# 8525    0.000000
# 9908    0.000000
#
# [4983 rows x 20 columns]

# %%
sns.set(rc={'figure.figsize':(19.7, 8.27)})
sns.heatmap(
  df.isnull(),
  yticklabels=False,
  cbar=False,
  cmap='viridis'
)

plt.show()

# %%
df
# Out:
#                           ResponseName  ReleaseDate  Metacritic  \
# 27    Counter-Strike: Global Offensive  Aug 21 2012          83
# 23                              Dota 2   Jul 9 2013          90
# 20                     Team Fortress 2  Oct 10 2007          92
# 1365       The Elder Scrolls V: Skyrim  Nov 10 2011          94
# 3088                Grand Theft Auto V  Apr 13 2015          96
# ...                                ...          ...         ...
# 9030                            Bonsai  Feb 18 2016           0
# 8948                         Spellbind   Mar 4 2016           0
# 9932                       Galaxy Golf  Aug 24 2016           0
# 8525                        Nordenfelt  Jan 14 2016           0
# 9908                         The Tribe  Aug 26 2016           0
#
#       RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 27                1427633   False           False         False
# 23                 590480    True           False         False
# 20                 383949    True           False         False
# 1365               182587   False           False         False
# 3088               136846   False           False         False
# ...                   ...     ...             ...           ...
# 9030                    0   False           False          True
# 8948                    0   False           False          True
# 9932                    0   False           False          True
# 8525                    0   False           False          True
# 9908                    0   False           False          True
#
#       GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 27             True             False          False            False
# 23             True             False          False             True
# 20             True             False          False            False
# 1365          False             False          False            False
# 3088           True              True          False            False
# ...             ...               ...            ...              ...
# 9030          False             False           True            False
# 8948          False              True           True            False
# 9932          False             False           True            False
# 8525           True             False          False            False
# 9908           True              True          False            False
#
#       GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 27         False              False               False              False
# 23         False              False               False               True
# 20         False              False               False               True
# 1365        True              False               False              False
# 3088       False              False               False              False
# ...          ...                ...                 ...                ...
# 9030       False               True               False              False
# 8948       False              False               False              False
# 9932       False              False               False              False
# 8525       False              False               False              False
# 9908       False              False               False              False
#
#       GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial  \
# 27            False          False                        False         14.99
# 23            False          False                        False          0.00
# 20            False          False                        False          0.00
# 1365          False          False                        False         19.99
# 3088          False          False                        False         59.99
# ...             ...            ...                          ...           ...
# 9030          False          False                        False          0.99
# 8948          False          False                        False          2.99
# 9932           True          False                        False          4.99
# 8525          False          False                        False          8.99
# 9908          False          False                        False          4.99
#
#            score
# 27    932.291667
# 23    675.553849
# 20    613.637150
# 1365  553.530790
# 3088  547.927584
# ...          ...
# 9030    0.000000
# 8948    0.000000
# 9932    0.000000
# 8525    0.000000
# 9908    0.000000
#
# [4983 rows x 20 columns]

# %%
df.sort_values(by='score',ascending=False)
# Out:
#                                ResponseName  ReleaseDate  Metacritic  \
# 27         Counter-Strike: Global Offensive  Aug 21 2012          83
# 23                                   Dota 2   Jul 9 2013          90
# 20                          Team Fortress 2  Oct 10 2007          92
# 1365            The Elder Scrolls V: Skyrim  Nov 10 2011          94
# 3088                     Grand Theft Auto V  Apr 13 2015          96
# ...                                     ...          ...         ...
# 9897                                hackmud  Sep 22 2016           0
# 9000  Red Comrades 2: For the Great Justice  Sep 22 2016           0
# 9001           The Treasures of Montezuma 5  Mar 10 2016           0
# 9002                            Tokyo Babel  Mar 31 2016           0
# 9908                              The Tribe  Aug 26 2016           0
#
#       RecommendationCount  IsFree  GenreIsNonGame  GenreIsIndie  \
# 27                1427633   False           False         False
# 23                 590480    True           False         False
# 20                 383949    True           False         False
# 1365               182587   False           False         False
# 3088               136846   False           False         False
# ...                   ...     ...             ...           ...
# 9897                    0   False           False          True
# 9000                    0   False           False         False
# 9001                    0   False           False         False
# 9002                    0   False           False         False
# 9908                    0   False           False          True
#
#       GenreIsAction  GenreIsAdventure  GenreIsCasual  GenreIsStrategy  \
# 27             True             False          False            False
# 23             True             False          False             True
# 20             True             False          False            False
# 1365          False             False          False            False
# 3088           True              True          False            False
# ...             ...               ...            ...              ...
# 9897          False             False          False            False
# 9000          False              True           True            False
# 9001          False             False           True            False
# 9002          False              True          False            False
# 9908           True              True          False            False
#
#       GenreIsRPG  GenreIsSimulation  GenreIsEarlyAccess  GenreIsFreeToPlay  \
# 27         False              False               False              False
# 23         False              False               False               True
# 20         False              False               False               True
# 1365        True              False               False              False
# 3088       False              False               False              False
# ...          ...                ...                 ...                ...
# 9897        True               True               False              False
# 9000       False              False               False              False
# 9001       False              False               False              False
# 9002       False              False               False              False
# 9908       False              False               False              False
#
#       GenreIsSports  GenreIsRacing  GenreIsMassivelyMultiplayer  PriceInitial  \
# 27            False          False                        False         14.99
# 23            False          False                        False          0.00
# 20            False          False                        False          0.00
# 1365          False          False                        False         19.99
# 3088          False          False                        False         59.99
# ...             ...            ...                          ...           ...
# 9897          False          False                         True          0.00
# 9000          False          False                        False          0.00
# 9001          False          False                        False          6.99
# 9002          False          False                        False         34.99
# 9908          False          False                        False          4.99
#
#            score
# 27    932.291667
# 23    675.553849
# 20    613.637150
# 1365  553.530790
# 3088  547.927584
# ...          ...
# 9897    0.000000
# 9000    0.000000
# 9001    0.000000
# 9002    0.000000
# 9908    0.000000
#
# [4983 rows x 20 columns]

# %%
df
df.to_csv('game_rank.csv')

# %%
for i in list(df):
   print(i)
# Out:
# ResponseName
# ReleaseDate
# Metacritic
# RecommendationCount
# IsFree
# GenreIsNonGame
# GenreIsIndie
# GenreIsAction
# GenreIsAdventure
# GenreIsCasual
# GenreIsStrategy
# GenreIsRPG
# GenreIsSimulation
# GenreIsEarlyAccess
# GenreIsFreeToPlay
# GenreIsSports
# GenreIsRacing
# GenreIsMassivelyMultiplayer
# PriceInitial
# score

# %%
# -*- coding:utf-8 -*-  
# csv转换成json
import csv
import json
 
file_path = "game_rank.csv"
# 指定encodeing='utf-8'中文防止乱码
csvfile = open(file_path,'r', encoding='utf-8')
jsonfile = open('games-data.json', 'w',encoding='utf-8')
 
# 指定列名
fieldnames = ("number","ResponseName",
"ReleaseDate",
"Metacritic",
"RecommendationCount",
"IsFree",
"GenreIsNonGame",
"GenreIsIndie",
"GenreIsAction",
"GenreIsAdventure",
"GenreIsCasual",
"GenreIsStrategy",
"GenreIsRPG",
"GenreIsSimulation",
"GenreIsEarlyAccess",
"GenreIsFreeToPlay",
"GenreIsSports",
"GenreIsRacing",
"GenreIsMassivelyMultiplayer",
"PriceInitial",
"score")
 
reader = csv.DictReader( csvfile, fieldnames)
# 指定ensure_ascii=False 为了不让中文显示为ascii字符码
out = json.dumps( [ row for row in reader ] ,ensure_ascii=False)
 
jsonfile.write(out)
# Out:
# 2873656

# %%
f = open('games-data.json')
data = json.load(f)
f.close()
data
# Out:
# [{'number': '',
#   'ResponseName': 'ResponseName',
#   'ReleaseDate': 'ReleaseDate',
#   'Metacritic': 'Metacritic',
#   'RecommendationCount': 'RecommendationCount',
#   'IsFree': 'IsFree',
#   'GenreIsNonGame': 'GenreIsNonGame',
#   'GenreIsIndie': 'GenreIsIndie',
#   'GenreIsAction': 'GenreIsAction',
#   'GenreIsAdventure': 'GenreIsAdventure',
#   'GenreIsCasual': 'GenreIsCasual',
#   'GenreIsStrategy': 'GenreIsStrategy',
#   'GenreIsRPG': 'GenreIsRPG',
#   'GenreIsSimulation': 'GenreIsSimulation',
#   'GenreIsEarlyAccess': 'GenreIsEarlyAccess',
#   'GenreIsFreeToPlay': 'GenreIsFreeToPlay',
#   'GenreIsSports': 'GenreIsSports',
#   'GenreIsRacing': 'GenreIsRacing',
#   'GenreIsMassivelyMultiplayer': 'GenreIsMassivelyMultiplayer',
#   'PriceInitial': 'PriceInitial',
#   'score': 'score'},
#  {'number': '27',
#   'ResponseName': 'Counter-Strike: Global Offensive',
#   'ReleaseDate': 'Aug 21 2012',
#   'Metacritic': '83',
#   'RecommendationCount': '1427633',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '932.2916666666667'},
#  {'number': '23',
#   'ResponseName': 'Dota 2',
#   'ReleaseDate': 'Jul 9 2013',
#   'Metacritic': '90',
#   'RecommendationCount': '590480',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '675.5538494487029'},
#  {'number': '20',
#   'ResponseName': 'Team Fortress 2',
#   'ReleaseDate': 'Oct 10 2007',
#   'Metacritic': '92',
#   'RecommendationCount': '383949',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '613.6371503273834'},
#  {'number': '1365',
#   'ResponseName': 'The Elder Scrolls V: Skyrim',
#   'ReleaseDate': 'Nov 10 2011',
#   'Metacritic': '94',
#   'RecommendationCount': '182587',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '553.5307904178921'},
#  {'number': '3088',
#   'ResponseName': 'Grand Theft Auto V',
#   'ReleaseDate': 'Apr 13 2015',
#   'Metacritic': '96',
#   'RecommendationCount': '136846',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '547.9275836296863'},
#  {'number': '928',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 'Apr 18 2011',
#   'Metacritic': '95',
#   'RecommendationCount': '73144',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4088946237116'},
#  {'number': '26',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 'Apr 18 2011',
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '24',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 'Apr 18 2011',
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '22',
#   'ResponseName': 'Left 4 Dead 2',
#   'ReleaseDate': 'Nov 16 2009',
#   'Metacritic': '89',
#   'RecommendationCount': '140726',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '512.8281429529391'},
#  {'number': '10',
#   'ResponseName': 'Half-Life 2',
#   'ReleaseDate': 'Nov 16 2004',
#   'Metacritic': '96',
#   'RecommendationCount': '35792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '512.5354345269408'},
#  {'number': '273',
#   'ResponseName': 'BioShock Infinite',
#   'ReleaseDate': 'Mar 25 2013',
#   'Metacritic': '94',
#   'RecommendationCount': '55512',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '509.02530476436635'},
#  {'number': '232',
#   'ResponseName': 'BioShock(tm)',
#   'ReleaseDate': 'Aug 21 2007',
#   'Metacritic': '96',
#   'RecommendationCount': '16260',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '505.694740875281'},
#  {'number': '6',
#   'ResponseName': 'Half-Life',
#   'ReleaseDate': 'Nov 8 1998',
#   'Metacritic': '96',
#   'RecommendationCount': '12486',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '504.37297260570466'},
#  {'number': '3612',
#   'ResponseName': 'The Witcher(r) 3: Wild Hunt',
#   'ReleaseDate': 'May 18 2015',
#   'Metacritic': '93',
#   'RecommendationCount': '50325',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '502.00032807801443'},
#  {'number': '7292',
#   'ResponseName': 'Undertale',
#   'ReleaseDate': 'Sep 15 2015',
#   'Metacritic': '92',
#   'RecommendationCount': '60314',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '500.2904428752581'},
#  {'number': '1205',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 'Sep 21 2010',
#   'Metacritic': '90',
#   'RecommendationCount': '85790',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.79623737333054'},
#  {'number': '276',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 'Sep 21 2010',
#   'Metacritic': '90',
#   'RecommendationCount': '85750',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.78222817068536'},
#  {'number': '1198',
#   'ResponseName': 'Borderlands 2',
#   'ReleaseDate': 'Sep 17 2012',
#   'Metacritic': '89',
#   'RecommendationCount': '86362',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '493.7882356378238'},
#  {'number': '579',
#   'ResponseName': 'The Elder Scrolls IV: Oblivion(r) Game of the Year Edition',
#   'ReleaseDate': 'Jun 16 2009',
#   'Metacritic': '94',
#   'RecommendationCount': '7792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '492.3123260086217'},
#  {'number': '631',
#   'ResponseName': 'Mass Effect 2',
#   'ReleaseDate': 'Jan 26 2010',
#   'Metacritic': '94',
#   'RecommendationCount': '7263',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '492.1270543036387'},
#  {'number': '12040',
#   'ResponseName': 'Sid Meiers Civilization(r) VI',
#   'ReleaseDate': 'Oct 20 2016',
#   'Metacritic': '94',
#   'RecommendationCount': '7201',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '492.1053400395386'},
#  {'number': '358',
#   'ResponseName': 'Grand Theft Auto: Vice City',
#   'ReleaseDate': 'Jan 10 2011',
#   'Metacritic': '94',
#   'RecommendationCount': '4866',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '491.287552835124'},
#  {'number': '6602',
#   'ResponseName': 'Divinity: Original Sin - Enhanced Edition',
#   'ReleaseDate': 'Oct 27 2015',
#   'Metacritic': '94',
#   'RecommendationCount': '2900',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '490.5990005251116'},
#  {'number': '57',
#   'ResponseName': 'QUAKE',
#   'ReleaseDate': 'Aug 3 2007',
#   'Metacritic': '94',
#   'RecommendationCount': '1266',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '490.02672459705445'},
#  {'number': '962',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 'Oct 25 2006',
#   'Metacritic': '94',
#   'RecommendationCount': '888',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.89433763205716'},
#  {'number': '824',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 'Oct 25 2006',
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '144',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 'Oct 25 2006',
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '359',
#   'ResponseName': 'Grand Theft Auto: San Andreas',
#   'ReleaseDate': 'Jan 6 2011',
#   'Metacritic': '93',
#   'RecommendationCount': '14209',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '489.3514190096475'},
#  {'number': '1904',
#   'ResponseName': 'PAYDAY 2',
#   'ReleaseDate': 'Aug 13 2013',
#   'Metacritic': '79',
#   'RecommendationCount': '219763',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '488.4259433563575'},
#  {'number': '164',
#   'ResponseName': 'Company of Heroes',
#   'ReleaseDate': 'Jul 17 2007',
#   'Metacritic': '93',
#   'RecommendationCount': '3856',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '485.72548713499896'},
#  {'number': '357',
#   'ResponseName': 'Grand Theft Auto III',
#   'ReleaseDate': 'Jan 6 2011',
#   'Metacritic': '93',
#   'RecommendationCount': '2768',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '485.3444368230491'},
#  {'number': '411',
#   'ResponseName': 'Unreal Tournament 2004: Editors Choice Edition',
#   'ReleaseDate': 'Mar 17 2004',
#   'Metacritic': '93',
#   'RecommendationCount': '1318',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '484.8366032271599'},
#  {'number': '3479',
#   'ResponseName': 'METAL GEAR SOLID V: THE PHANTOM PAIN',
#   'ReleaseDate': 'Sep 1 2015',
#   'Metacritic': '91',
#   'RecommendationCount': '26956',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '483.3991349959455'},
#  {'number': '1637',
#   'ResponseName': 'Dishonored',
#   'ReleaseDate': 'Oct 8 2012',
#   'Metacritic': '91',
#   'RecommendationCount': '25429',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.86433368496427'},
#  {'number': '0',
#   'ResponseName': 'Counter-Strike',
#   'ReleaseDate': 'Nov 1 2000',
#   'Metacritic': '88',
#   'RecommendationCount': '68991',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.49605582573855'},
#  {'number': '367',
#   'ResponseName': 'Grand Theft Auto IV',
#   'ReleaseDate': 'Dec 2 2008',
#   'Metacritic': '90',
#   'RecommendationCount': '36012',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.36248514148946'},
#  {'number': '239',
#   'ResponseName': 'Call of Duty(r) 4: Modern Warfare(r)',
#   'ReleaseDate': 'Nov 12 2007',
#   'Metacritic': '92',
#   'RecommendationCount': '5983',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.2620931523251'},
#  {'number': '1477',
#   'ResponseName': 'Terraria',
#   'ReleaseDate': 'May 16 2011',
#   'Metacritic': '83',
#   'RecommendationCount': '139819',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '481.2604842829588'},
#  {'number': '169',
#   'ResponseName': 'Rome: Total War(tm) - Collection',
#   'ReleaseDate': 'Aug 28 2007',
#   'Metacritic': '92',
#   'RecommendationCount': '5160',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.97385380789973'},
#  {'number': '2265',
#   'ResponseName': 'System Shock 2',
#   'ReleaseDate': 'May 10 2013',
#   'Metacritic': '92',
#   'RecommendationCount': '3216',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.2930065593422'},
#  {'number': '1541',
#   'ResponseName': 'Batman: Arkham City - Game of the Year Edition',
#   'ReleaseDate': 'Sep 7 2012',
#   'Metacritic': '91',
#   'RecommendationCount': '16418',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.7084105590629'},
#  {'number': '419',
#   'ResponseName': 'Tom Clancys Splinter Cell Chaos Theory(r)',
#   'ReleaseDate': 'Aug 27 2009',
#   'Metacritic': '92',
#   'RecommendationCount': '1230',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5974496480071'},
#  {'number': '412',
#   'ResponseName': 'Unreal Tournament: Game of the Year Edition',
#   'ReleaseDate': 'Mar 17 2008',
#   'Metacritic': '92',
#   'RecommendationCount': '1140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5659289420554'},
#  {'number': '1785',
#   'ResponseName': 'Thief(tm) Gold',
#   'ReleaseDate': 'May 22 2012',
#   'Metacritic': '92',
#   'RecommendationCount': '1116',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '6.99',
#   'score': '479.55752342046827'},
#  {'number': '1579',
#   'ResponseName': 'Galactic Civilizations(r) II: Ultimate Edition',
#   'ReleaseDate': 'Dec 2 2011',
#   'Metacritic': '92',
#   'RecommendationCount': '827',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.45630693135655'},
#  {'number': '584',
#   'ResponseName': 'Fallout 3: Game of the Year Edition',
#   'ReleaseDate': 'Dec 17 2009',
#   'Metacritic': '91',
#   'RecommendationCount': '15420',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.3588809530647'},
#  {'number': '7677',
#   'ResponseName': 'Out of the Park Baseball 17',
#   'ReleaseDate': 'Mar 22 2016',
#   'Metacritic': '92',
#   'RecommendationCount': '283',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '479.2657817753816'},
#  {'number': '966',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 'Mar 26 2010',
#   'Metacritic': '91',
#   'RecommendationCount': '13358',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63670655670376'},
#  {'number': '841',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 'Mar 26 2010',
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '844',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 'Mar 26 2010',
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '1227',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 'Oct 10 2007',
#   'Metacritic': '90',
#   'RecommendationCount': '27546',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.39743740162913'},
#  {'number': '18',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 'Oct 10 2007',
#   'Metacritic': '90',
#   'RecommendationCount': '27535',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.3935848709017'},
#  {'number': '2593',
#   'ResponseName': 'Rocket League(r)',
#   'ReleaseDate': 'Jul 7 2015',
#   'Metacritic': '86',
#   'RecommendationCount': '86627',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.25604660534844'},
#  {'number': '1835',
#   'ResponseName': 'Mark of the Ninja',
#   'ReleaseDate': 'Oct 16 2012',
#   'Metacritic': '91',
#   'RecommendationCount': '11059',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '477.83152763466984'},
#  {'number': '11',
#   'ResponseName': 'Counter-Strike: Source',
#   'ReleaseDate': 'Nov 1 2004',
#   'Metacritic': '88',
#   'RecommendationCount': '53931',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.22159102981414'},
#  {'number': '2261',
#   'ResponseName': 'Deus Ex: Human Revolution - Directors Cut',
#   'ReleaseDate': 'Oct 25 2013',
#   'Metacritic': '91',
#   'RecommendationCount': '8724',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.01374043025527'},
#  {'number': '2018',
#   'ResponseName': 'FEZ',
#   'ReleaseDate': 'May 1 2013',
#   'Metacritic': '91',
#   'RecommendationCount': '8516',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.9408925765001'},
#  {'number': '576',
#   'ResponseName': 'Fallout 3',
#   'ReleaseDate': 'Oct 28 2008',
#   'Metacritic': '91',
#   'RecommendationCount': '8031',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.7710309944269'},
#  {'number': '2028',
#   'ResponseName': 'Brothers - A Tale of Two Sons',
#   'ReleaseDate': 'Sep 3 2013',
#   'Metacritic': '90',
#   'RecommendationCount': '22471',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '476.62001981601713'},
#  {'number': '1171',
#   'ResponseName': 'Dragon Age: Origins - Ultimate Edition',
#   'ReleaseDate': 'Oct 26 2010',
#   'Metacritic': '91',
#   'RecommendationCount': '6848',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '476.35670882619456'},
#  {'number': '495',
#   'ResponseName': 'Dragon Age: Origins',
#   'ReleaseDate': 'Nov 5 2009',
#   'Metacritic': '91',
#   'RecommendationCount': '4146',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.4103871875101'},
#  {'number': '488',
#   'ResponseName': 'Crysis',
#   'ReleaseDate': 'Sep 17 2008',
#   'Metacritic': '91',
#   'RecommendationCount': '3881',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.31757621998554'},
#  {'number': '1546',
#   'ResponseName': 'XCOM: Enemy Unknown',
#   'ReleaseDate': 'Oct 8 2012',
#   'Metacritic': '89',
#   'RecommendationCount': '31794',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '474.67688138921795'},
#  {'number': '78',
#   'ResponseName': 'Call of Duty(r)',
#   'ReleaseDate': 'Oct 13 2006',
#   'Metacritic': '91',
#   'RecommendationCount': '851',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.2563791196103'},
#  {'number': '196',
#   'ResponseName': 'The Longest Journey',
#   'ReleaseDate': 'May 1 2007',
#   'Metacritic': '91',
#   'RecommendationCount': '737',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.2164528920714'},
#  {'number': '720',
#   'ResponseName': 'STAR WARS(tm) Jedi Knight: Dark Forces II',
#   'ReleaseDate': 'Sep 16 2009',
#   'Metacritic': '91',
#   'RecommendationCount': '735',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '5.99',
#   'score': '474.2157524319392'},
#  {'number': '418',
#   'ResponseName': 'Tom Clancys Splinter Cell(r)',
#   'ReleaseDate': 'Apr 1 2008',
#   'Metacritic': '91',
#   'RecommendationCount': '586',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.16356815208576'},
#  {'number': '561',
#   'ResponseName': 'Street Fighter(r) IV',
#   'ReleaseDate': 'Jul 7 2009',
#   'Metacritic': '91',
#   'RecommendationCount': '343',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.0784622460161'},
#  {'number': '3119',
#   'ResponseName': 'Freespace 2',
#   'ReleaseDate': 'Jun 6 2014',
#   'Metacritic': '91',
#   'RecommendationCount': '163',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.0154208341126'},
#  {'number': '6640',
#   'ResponseName': 'DARK SOULS(tm) III',
#   'ReleaseDate': 'Apr 11 2016',
#   'Metacritic': '89',
#   'RecommendationCount': '26844',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '472.94324256187224'},
#  {'number': '327',
#   'ResponseName': 'Empire: Total War(tm)',
#   'ReleaseDate': 'Mar 3 2009',
#   'Metacritic': '90',
#   'RecommendationCount': '11234',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '472.6844845629094'},
#  {'number': '1934',
#   'ResponseName': 'Far Cry 3',
#   'ReleaseDate': 'Dec 4 2012',
#   'Metacritic': '88',
#   'RecommendationCount': '36011',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '470.9454682447566'},
#  {'number': '19',
#   'ResponseName': 'Half-Life 2: Episode Two',
#   'ReleaseDate': 'Oct 10 2007',
#   'Metacritic': '90',
#   'RecommendationCount': '6104',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '470.88780432366025'},
#  {'number': '2290',
#   'ResponseName': 'Spelunky',
#   'ReleaseDate': 'Aug 8 2013',
#   'Metacritic': '90',
#   'RecommendationCount': '6079',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.879048572007'},
#  {'number': '651',
#   'ResponseName': 'Braid',
#   'ReleaseDate': 'Apr 10 2009',
#   'Metacritic': '90',
#   'RecommendationCount': '5069',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.5253162052152'},
#  {'number': '212',
#   'ResponseName': 'Deus Ex: Game of the Year Edition',
#   'ReleaseDate': 'Mar 29 2007',
#   'Metacritic': '90',
#   'RecommendationCount': '3706',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
# ...
#   'ReleaseDate': 'Aug 8 2012',
#   'Metacritic': '74',
#   'RecommendationCount': '317',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52768959763'},
#  {'number': '8377',
#   'ResponseName': 'Project Highrise',
#   'ReleaseDate': 'Sep 8 2016',
#   'Metacritic': '74',
#   'RecommendationCount': '315',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52698913749776'},
#  {'number': '2669',
#   'ResponseName': 'Shadows: Heretic Kingdoms',
#   'ReleaseDate': 'Nov 20 2014',
#   'Metacritic': '74',
#   'RecommendationCount': '306',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52383706690256'},
#  {'number': '2108',
#   'ResponseName': 'Incredipede',
#   'ReleaseDate': 'Mar 18 2013',
#   'Metacritic': '74',
#   'RecommendationCount': '301',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52208591657194'},
#  {'number': '4709',
#   'ResponseName': 'Annas Quest',
#   'ReleaseDate': 'Jul 2 2015',
#   'Metacritic': '74',
#   'RecommendationCount': '299',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.5213854564397'},
#  {'number': '3426',
#   'ResponseName': 'Action Henk',
#   'ReleaseDate': 'May 11 2015',
#   'Metacritic': '74',
#   'RecommendationCount': '295',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5199845361751'},
#  {'number': '7390',
#   'ResponseName': 'Warhammer 40000: Deathwatch - Enhanced Edition',
#   'ReleaseDate': 'Oct 16 2015',
#   'Metacritic': '74',
#   'RecommendationCount': '277',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5136803949848'},
#  {'number': '3669',
#   'ResponseName': 'TRI: Of Friendship and Madness',
#   'ReleaseDate': 'Oct 9 2014',
#   'Metacritic': '74',
#   'RecommendationCount': '232',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.49792004200896'},
#  {'number': '220',
#   'ResponseName': 'Runaway A Road Adventure',
#   'ReleaseDate': 'Mar 14 2007',
#   'Metacritic': '74',
#   'RecommendationCount': '212',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.49091544068636'},
#  {'number': '1614',
#   'ResponseName': 'Snapshot',
#   'ReleaseDate': 'Aug 30 2012',
#   'Metacritic': '74',
#   'RecommendationCount': '202',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.48741314002507'},
#  {'number': '3145',
#   'ResponseName': 'Drox Operative',
#   'ReleaseDate': 'Feb 18 2014',
#   'Metacritic': '74',
#   'RecommendationCount': '185',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4814592289008'},
#  {'number': '84',
#   'ResponseName': 'ARMA: Combat Operations',
#   'ReleaseDate': 'Mar 12 2008',
#   'Metacritic': '74',
#   'RecommendationCount': '181',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.4800583086363'},
#  {'number': '8526',
#   'ResponseName': 'Neon Chrome',
#   'ReleaseDate': 'Apr 28 2016',
#   'Metacritic': '74',
#   'RecommendationCount': '165',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.4744546275782'},
#  {'number': '3571',
#   'ResponseName': 'Cloud Chamber',
#   'ReleaseDate': 'Aug 7 2014',
#   'Metacritic': '74',
#   'RecommendationCount': '141',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'True',
#   'PriceInitial': '19.99',
#   'score': '385.4660491059911'},
#  {'number': '3801',
#   'ResponseName': 'Space Colony: Steam Edition',
#   'ReleaseDate': 'Apr 30 2015',
#   'Metacritic': '74',
#   'RecommendationCount': '140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.46569887592494'},
#  {'number': '175',
#   'ResponseName': 'Cossacks: European Wars',
#   'ReleaseDate': 'Aug 26 2011',
#   'Metacritic': '74',
#   'RecommendationCount': '135',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '385.46394772559427'},
#  {'number': '2391',
#   'ResponseName': 'Where is my Heart?',
#   'ReleaseDate': 'May 29 2014',
#   'Metacritic': '74',
#   'RecommendationCount': '128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.46149611513135'},
#  {'number': '7250',
#   'ResponseName': 'Sora',
#   'ReleaseDate': 'Jan 5 2016',
#   'Metacritic': '74',
#   'RecommendationCount': '124',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '8.99',
#   'score': '385.4600951948668'},
#  {'number': '4151',
#   'ResponseName': 'Crookz - The Big Heist',
#   'ReleaseDate': 'Aug 25 2015',
#   'Metacritic': '74',
#   'RecommendationCount': '103',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4527403634781'},
#  {'number': '2640',
#   'ResponseName': 'Shadow Warrior',
#   'ReleaseDate': 'Sep 26 2013',
#   'Metacritic': '73',
#   'RecommendationCount': '10697',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '383.9547443507306'},
#  {'number': '3223',
#   'ResponseName': 'A Story About My Uncle',
#   'ReleaseDate': 'May 28 2014',
#   'Metacritic': '73',
#   'RecommendationCount': '6675',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '12.99',
#   'score': '382.546119024754'},
#  {'number': '2920',
#   'ResponseName': 'Lords Of The Fallen(tm)',
#   'ReleaseDate': 'Oct 28 2014',
#   'Metacritic': '73',
#   'RecommendationCount': '6584',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '382.5142480887361'},
#  {'number': '1063',
#   'ResponseName': 'War of the Roses',
#   'ReleaseDate': 'Feb 6 2013',
#   'Metacritic': '73',
#   'RecommendationCount': '4417',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '381.75529953543145'},
#  {'number': '3496',
#   'ResponseName': 'The Room',
#   'ReleaseDate': 'Jul 28 2014',
#   'Metacritic': '73',
#   'RecommendationCount': '4054',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '381.6281660214261'},
#  {'number': '7385',
#   'ResponseName': 'Punch Club',
#   'ReleaseDate': 'Jan 8 2016',
#   'Metacritic': '73',
#   'RecommendationCount': '3664',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '381.49157629563524'},
#  {'number': '1537',
#   'ResponseName': 'Worms Revolution',
#   'ReleaseDate': 'Oct 10 2012',
#   'Metacritic': '73',
#   'RecommendationCount': '3320',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '381.37109715288636'},
#  ...]

# %%
regex = '19\d\d$|20\d\d$'
for i in data:
    if re.finditer(regex,i['ReleaseDate']) is not None:
        for t in re.finditer(regex,i['ReleaseDate']):
            i['ReleaseDate']=int(t.group())
data
# Out:
# [{'number': '',
#   'ResponseName': 'ResponseName',
#   'ReleaseDate': 'ReleaseDate',
#   'Metacritic': 'Metacritic',
#   'RecommendationCount': 'RecommendationCount',
#   'IsFree': 'IsFree',
#   'GenreIsNonGame': 'GenreIsNonGame',
#   'GenreIsIndie': 'GenreIsIndie',
#   'GenreIsAction': 'GenreIsAction',
#   'GenreIsAdventure': 'GenreIsAdventure',
#   'GenreIsCasual': 'GenreIsCasual',
#   'GenreIsStrategy': 'GenreIsStrategy',
#   'GenreIsRPG': 'GenreIsRPG',
#   'GenreIsSimulation': 'GenreIsSimulation',
#   'GenreIsEarlyAccess': 'GenreIsEarlyAccess',
#   'GenreIsFreeToPlay': 'GenreIsFreeToPlay',
#   'GenreIsSports': 'GenreIsSports',
#   'GenreIsRacing': 'GenreIsRacing',
#   'GenreIsMassivelyMultiplayer': 'GenreIsMassivelyMultiplayer',
#   'PriceInitial': 'PriceInitial',
#   'score': 'score'},
#  {'number': '27',
#   'ResponseName': 'Counter-Strike: Global Offensive',
#   'ReleaseDate': 2012,
#   'Metacritic': '83',
#   'RecommendationCount': '1427633',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '932.2916666666667'},
#  {'number': '23',
#   'ResponseName': 'Dota 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '590480',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '675.5538494487029'},
#  {'number': '20',
#   'ResponseName': 'Team Fortress 2',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '383949',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '613.6371503273834'},
#  {'number': '1365',
#   'ResponseName': 'The Elder Scrolls V: Skyrim',
#   'ReleaseDate': 2011,
#   'Metacritic': '94',
#   'RecommendationCount': '182587',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '553.5307904178921'},
#  {'number': '3088',
#   'ResponseName': 'Grand Theft Auto V',
#   'ReleaseDate': 2015,
#   'Metacritic': '96',
#   'RecommendationCount': '136846',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '547.9275836296863'},
#  {'number': '928',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73144',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4088946237116'},
#  {'number': '26',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '24',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '22',
#   'ResponseName': 'Left 4 Dead 2',
#   'ReleaseDate': 2009,
#   'Metacritic': '89',
#   'RecommendationCount': '140726',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '512.8281429529391'},
#  {'number': '10',
#   'ResponseName': 'Half-Life 2',
#   'ReleaseDate': 2004,
#   'Metacritic': '96',
#   'RecommendationCount': '35792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '512.5354345269408'},
#  {'number': '273',
#   'ResponseName': 'BioShock Infinite',
#   'ReleaseDate': 2013,
#   'Metacritic': '94',
#   'RecommendationCount': '55512',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '509.02530476436635'},
#  {'number': '232',
#   'ResponseName': 'BioShock(tm)',
#   'ReleaseDate': 2007,
#   'Metacritic': '96',
#   'RecommendationCount': '16260',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '505.694740875281'},
#  {'number': '6',
#   'ResponseName': 'Half-Life',
#   'ReleaseDate': 1998,
#   'Metacritic': '96',
#   'RecommendationCount': '12486',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '504.37297260570466'},
#  {'number': '3612',
#   'ResponseName': 'The Witcher(r) 3: Wild Hunt',
#   'ReleaseDate': 2015,
#   'Metacritic': '93',
#   'RecommendationCount': '50325',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '502.00032807801443'},
#  {'number': '7292',
#   'ResponseName': 'Undertale',
#   'ReleaseDate': 2015,
#   'Metacritic': '92',
#   'RecommendationCount': '60314',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '500.2904428752581'},
#  {'number': '1205',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 2010,
#   'Metacritic': '90',
#   'RecommendationCount': '85790',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.79623737333054'},
#  {'number': '276',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 2010,
#   'Metacritic': '90',
#   'RecommendationCount': '85750',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.78222817068536'},
#  {'number': '1198',
#   'ResponseName': 'Borderlands 2',
#   'ReleaseDate': 2012,
#   'Metacritic': '89',
#   'RecommendationCount': '86362',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '493.7882356378238'},
#  {'number': '579',
#   'ResponseName': 'The Elder Scrolls IV: Oblivion(r) Game of the Year Edition',
#   'ReleaseDate': 2009,
#   'Metacritic': '94',
#   'RecommendationCount': '7792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '492.3123260086217'},
#  {'number': '631',
#   'ResponseName': 'Mass Effect 2',
#   'ReleaseDate': 2010,
#   'Metacritic': '94',
#   'RecommendationCount': '7263',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '492.1270543036387'},
#  {'number': '12040',
#   'ResponseName': 'Sid Meiers Civilization(r) VI',
#   'ReleaseDate': 2016,
#   'Metacritic': '94',
#   'RecommendationCount': '7201',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '492.1053400395386'},
#  {'number': '358',
#   'ResponseName': 'Grand Theft Auto: Vice City',
#   'ReleaseDate': 2011,
#   'Metacritic': '94',
#   'RecommendationCount': '4866',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '491.287552835124'},
#  {'number': '6602',
#   'ResponseName': 'Divinity: Original Sin - Enhanced Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '94',
#   'RecommendationCount': '2900',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '490.5990005251116'},
#  {'number': '57',
#   'ResponseName': 'QUAKE',
#   'ReleaseDate': 2007,
#   'Metacritic': '94',
#   'RecommendationCount': '1266',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '490.02672459705445'},
#  {'number': '962',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '888',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.89433763205716'},
#  {'number': '824',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '144',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '359',
#   'ResponseName': 'Grand Theft Auto: San Andreas',
#   'ReleaseDate': 2011,
#   'Metacritic': '93',
#   'RecommendationCount': '14209',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '489.3514190096475'},
#  {'number': '1904',
#   'ResponseName': 'PAYDAY 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '79',
#   'RecommendationCount': '219763',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '488.4259433563575'},
#  {'number': '164',
#   'ResponseName': 'Company of Heroes',
#   'ReleaseDate': 2007,
#   'Metacritic': '93',
#   'RecommendationCount': '3856',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '485.72548713499896'},
#  {'number': '357',
#   'ResponseName': 'Grand Theft Auto III',
#   'ReleaseDate': 2011,
#   'Metacritic': '93',
#   'RecommendationCount': '2768',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '485.3444368230491'},
#  {'number': '411',
#   'ResponseName': 'Unreal Tournament 2004: Editors Choice Edition',
#   'ReleaseDate': 2004,
#   'Metacritic': '93',
#   'RecommendationCount': '1318',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '484.8366032271599'},
#  {'number': '3479',
#   'ResponseName': 'METAL GEAR SOLID V: THE PHANTOM PAIN',
#   'ReleaseDate': 2015,
#   'Metacritic': '91',
#   'RecommendationCount': '26956',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '483.3991349959455'},
#  {'number': '1637',
#   'ResponseName': 'Dishonored',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '25429',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.86433368496427'},
#  {'number': '0',
#   'ResponseName': 'Counter-Strike',
#   'ReleaseDate': 2000,
#   'Metacritic': '88',
#   'RecommendationCount': '68991',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.49605582573855'},
#  {'number': '367',
#   'ResponseName': 'Grand Theft Auto IV',
#   'ReleaseDate': 2008,
#   'Metacritic': '90',
#   'RecommendationCount': '36012',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.36248514148946'},
#  {'number': '239',
#   'ResponseName': 'Call of Duty(r) 4: Modern Warfare(r)',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '5983',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.2620931523251'},
#  {'number': '1477',
#   'ResponseName': 'Terraria',
#   'ReleaseDate': 2011,
#   'Metacritic': '83',
#   'RecommendationCount': '139819',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '481.2604842829588'},
#  {'number': '169',
#   'ResponseName': 'Rome: Total War(tm) - Collection',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '5160',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.97385380789973'},
#  {'number': '2265',
#   'ResponseName': 'System Shock 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '92',
#   'RecommendationCount': '3216',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.2930065593422'},
#  {'number': '1541',
#   'ResponseName': 'Batman: Arkham City - Game of the Year Edition',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '16418',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.7084105590629'},
#  {'number': '419',
#   'ResponseName': 'Tom Clancys Splinter Cell Chaos Theory(r)',
#   'ReleaseDate': 2009,
#   'Metacritic': '92',
#   'RecommendationCount': '1230',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5974496480071'},
#  {'number': '412',
#   'ResponseName': 'Unreal Tournament: Game of the Year Edition',
#   'ReleaseDate': 2008,
#   'Metacritic': '92',
#   'RecommendationCount': '1140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5659289420554'},
#  {'number': '1785',
#   'ResponseName': 'Thief(tm) Gold',
#   'ReleaseDate': 2012,
#   'Metacritic': '92',
#   'RecommendationCount': '1116',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '6.99',
#   'score': '479.55752342046827'},
#  {'number': '1579',
#   'ResponseName': 'Galactic Civilizations(r) II: Ultimate Edition',
#   'ReleaseDate': 2011,
#   'Metacritic': '92',
#   'RecommendationCount': '827',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.45630693135655'},
#  {'number': '584',
#   'ResponseName': 'Fallout 3: Game of the Year Edition',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '15420',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.3588809530647'},
#  {'number': '7677',
#   'ResponseName': 'Out of the Park Baseball 17',
#   'ReleaseDate': 2016,
#   'Metacritic': '92',
#   'RecommendationCount': '283',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '479.2657817753816'},
#  {'number': '966',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13358',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63670655670376'},
#  {'number': '841',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '844',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '1227',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '27546',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.39743740162913'},
#  {'number': '18',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '27535',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.3935848709017'},
#  {'number': '2593',
#   'ResponseName': 'Rocket League(r)',
#   'ReleaseDate': 2015,
#   'Metacritic': '86',
#   'RecommendationCount': '86627',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.25604660534844'},
#  {'number': '1835',
#   'ResponseName': 'Mark of the Ninja',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '11059',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '477.83152763466984'},
#  {'number': '11',
#   'ResponseName': 'Counter-Strike: Source',
#   'ReleaseDate': 2004,
#   'Metacritic': '88',
#   'RecommendationCount': '53931',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.22159102981414'},
#  {'number': '2261',
#   'ResponseName': 'Deus Ex: Human Revolution - Directors Cut',
#   'ReleaseDate': 2013,
#   'Metacritic': '91',
#   'RecommendationCount': '8724',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.01374043025527'},
#  {'number': '2018',
#   'ResponseName': 'FEZ',
#   'ReleaseDate': 2013,
#   'Metacritic': '91',
#   'RecommendationCount': '8516',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.9408925765001'},
#  {'number': '576',
#   'ResponseName': 'Fallout 3',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '8031',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.7710309944269'},
#  {'number': '2028',
#   'ResponseName': 'Brothers - A Tale of Two Sons',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '22471',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '476.62001981601713'},
#  {'number': '1171',
#   'ResponseName': 'Dragon Age: Origins - Ultimate Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '6848',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '476.35670882619456'},
#  {'number': '495',
#   'ResponseName': 'Dragon Age: Origins',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '4146',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.4103871875101'},
#  {'number': '488',
#   'ResponseName': 'Crysis',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '3881',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.31757621998554'},
#  {'number': '1546',
#   'ResponseName': 'XCOM: Enemy Unknown',
#   'ReleaseDate': 2012,
#   'Metacritic': '89',
#   'RecommendationCount': '31794',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '474.67688138921795'},
#  {'number': '78',
#   'ResponseName': 'Call of Duty(r)',
#   'ReleaseDate': 2006,
#   'Metacritic': '91',
#   'RecommendationCount': '851',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.2563791196103'},
#  {'number': '196',
#   'ResponseName': 'The Longest Journey',
#   'ReleaseDate': 2007,
#   'Metacritic': '91',
#   'RecommendationCount': '737',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.2164528920714'},
#  {'number': '720',
#   'ResponseName': 'STAR WARS(tm) Jedi Knight: Dark Forces II',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '735',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '5.99',
#   'score': '474.2157524319392'},
#  {'number': '418',
#   'ResponseName': 'Tom Clancys Splinter Cell(r)',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '586',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.16356815208576'},
#  {'number': '561',
#   'ResponseName': 'Street Fighter(r) IV',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '343',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.0784622460161'},
#  {'number': '3119',
#   'ResponseName': 'Freespace 2',
#   'ReleaseDate': 2014,
#   'Metacritic': '91',
#   'RecommendationCount': '163',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.0154208341126'},
#  {'number': '6640',
#   'ResponseName': 'DARK SOULS(tm) III',
#   'ReleaseDate': 2016,
#   'Metacritic': '89',
#   'RecommendationCount': '26844',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '472.94324256187224'},
#  {'number': '327',
#   'ResponseName': 'Empire: Total War(tm)',
#   'ReleaseDate': 2009,
#   'Metacritic': '90',
#   'RecommendationCount': '11234',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '472.6844845629094'},
#  {'number': '1934',
#   'ResponseName': 'Far Cry 3',
#   'ReleaseDate': 2012,
#   'Metacritic': '88',
#   'RecommendationCount': '36011',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '470.9454682447566'},
#  {'number': '19',
#   'ResponseName': 'Half-Life 2: Episode Two',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '6104',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '470.88780432366025'},
#  {'number': '2290',
#   'ResponseName': 'Spelunky',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '6079',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.879048572007'},
#  {'number': '651',
#   'ResponseName': 'Braid',
#   'ReleaseDate': 2009,
#   'Metacritic': '90',
#   'RecommendationCount': '5069',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.5253162052152'},
#  {'number': '212',
#   'ResponseName': 'Deus Ex: Game of the Year Edition',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '3706',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '6.99',
#   'score': '470.0479526250794'},
#  {'number': '568',
#   'ResponseName': 'World of Goo',
#   'ReleaseDate': 2008,
#   'Metacritic': '90',
#   'RecommendationCount': '2685',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
# ...
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.54730248133336'},
#  {'number': '1765',
#   'ResponseName': 'Unmechanical',
#   'ReleaseDate': 2012,
#   'Metacritic': '74',
#   'RecommendationCount': '317',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52768959763'},
#  {'number': '8377',
#   'ResponseName': 'Project Highrise',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '315',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52698913749776'},
#  {'number': '2669',
#   'ResponseName': 'Shadows: Heretic Kingdoms',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '306',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52383706690256'},
#  {'number': '2108',
#   'ResponseName': 'Incredipede',
#   'ReleaseDate': 2013,
#   'Metacritic': '74',
#   'RecommendationCount': '301',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52208591657194'},
#  {'number': '4709',
#   'ResponseName': 'Annas Quest',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '299',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.5213854564397'},
#  {'number': '3426',
#   'ResponseName': 'Action Henk',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '295',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5199845361751'},
#  {'number': '7390',
#   'ResponseName': 'Warhammer 40000: Deathwatch - Enhanced Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '277',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5136803949848'},
#  {'number': '3669',
#   'ResponseName': 'TRI: Of Friendship and Madness',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '232',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.49792004200896'},
#  {'number': '220',
#   'ResponseName': 'Runaway A Road Adventure',
#   'ReleaseDate': 2007,
#   'Metacritic': '74',
#   'RecommendationCount': '212',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.49091544068636'},
#  {'number': '1614',
#   'ResponseName': 'Snapshot',
#   'ReleaseDate': 2012,
#   'Metacritic': '74',
#   'RecommendationCount': '202',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.48741314002507'},
#  {'number': '3145',
#   'ResponseName': 'Drox Operative',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '185',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4814592289008'},
#  {'number': '84',
#   'ResponseName': 'ARMA: Combat Operations',
#   'ReleaseDate': 2008,
#   'Metacritic': '74',
#   'RecommendationCount': '181',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.4800583086363'},
#  {'number': '8526',
#   'ResponseName': 'Neon Chrome',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '165',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.4744546275782'},
#  {'number': '3571',
#   'ResponseName': 'Cloud Chamber',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '141',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'True',
#   'PriceInitial': '19.99',
#   'score': '385.4660491059911'},
#  {'number': '3801',
#   'ResponseName': 'Space Colony: Steam Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.46569887592494'},
#  {'number': '175',
#   'ResponseName': 'Cossacks: European Wars',
#   'ReleaseDate': 2011,
#   'Metacritic': '74',
#   'RecommendationCount': '135',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '385.46394772559427'},
#  {'number': '2391',
#   'ResponseName': 'Where is my Heart?',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.46149611513135'},
#  {'number': '7250',
#   'ResponseName': 'Sora',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '124',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '8.99',
#   'score': '385.4600951948668'},
#  {'number': '4151',
#   'ResponseName': 'Crookz - The Big Heist',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '103',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4527403634781'},
#  {'number': '2640',
#   'ResponseName': 'Shadow Warrior',
#   'ReleaseDate': 2013,
#   'Metacritic': '73',
#   'RecommendationCount': '10697',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '383.9547443507306'},
#  {'number': '3223',
#   'ResponseName': 'A Story About My Uncle',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '6675',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '12.99',
#   'score': '382.546119024754'},
#  {'number': '2920',
#   'ResponseName': 'Lords Of The Fallen(tm)',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '6584',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '382.5142480887361'},
#  {'number': '1063',
#   'ResponseName': 'War of the Roses',
#   'ReleaseDate': 2013,
#   'Metacritic': '73',
#   'RecommendationCount': '4417',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '381.75529953543145'},
#  {'number': '3496',
#   'ResponseName': 'The Room',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '4054',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '381.6281660214261'},
#  {'number': '7385',
#   'ResponseName': 'Punch Club',
#   'ReleaseDate': 2016,
#   'Metacritic': '73',
#   'RecommendationCount': '3664',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '381.49157629563524'},
#  {'number': '1537',
#   'ResponseName': 'Worms Revolution',
#   'ReleaseDate': 2012,
#   'Metacritic': '73',
#   'RecommendationCount': '3320',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '381.37109715288636'},
#  ...]

# %%
df = pd.DataFrame(data)
df.drop([0],inplace = True)
del df['number']
df
# Out:
#                           ResponseName ReleaseDate Metacritic  \
# 1     Counter-Strike: Global Offensive        2012         83
# 2                               Dota 2        2013         90
# 3                      Team Fortress 2        2007         92
# 4          The Elder Scrolls V: Skyrim        2011         94
# 5                   Grand Theft Auto V        2015         96
# ...                                ...         ...        ...
# 4979                            Bonsai        2016          0
# 4980                         Spellbind        2016          0
# 4981                       Galaxy Golf        2016          0
# 4982                        Nordenfelt        2016          0
# 4983                         The Tribe        2016          0
#
#      RecommendationCount IsFree GenreIsNonGame GenreIsIndie GenreIsAction  \
# 1                1427633  False          False        False          True
# 2                 590480   True          False        False          True
# 3                 383949   True          False        False          True
# 4                 182587  False          False        False         False
# 5                 136846  False          False        False          True
# ...                  ...    ...            ...          ...           ...
# 4979                   0  False          False         True         False
# 4980                   0  False          False         True         False
# 4981                   0  False          False         True         False
# 4982                   0  False          False         True          True
# 4983                   0  False          False         True          True
#
#      GenreIsAdventure GenreIsCasual GenreIsStrategy GenreIsRPG  \
# 1               False         False           False      False
# 2               False         False            True      False
# 3               False         False           False      False
# 4               False         False           False       True
# 5                True         False           False      False
# ...               ...           ...             ...        ...
# 4979            False          True           False      False
# 4980             True          True           False      False
# 4981            False          True           False      False
# 4982            False         False           False      False
# 4983             True         False           False      False
#
#      GenreIsSimulation GenreIsEarlyAccess GenreIsFreeToPlay GenreIsSports  \
# 1                False              False             False         False
# 2                False              False              True         False
# 3                False              False              True         False
# 4                False              False             False         False
# 5                False              False             False         False
# ...                ...                ...               ...           ...
# 4979              True              False             False         False
# 4980             False              False             False         False
# 4981             False              False             False          True
# 4982             False              False             False         False
# 4983             False              False             False         False
#
#      GenreIsRacing GenreIsMassivelyMultiplayer PriceInitial              score
# 1            False                       False        14.99  932.2916666666667
# 2            False                       False          0.0  675.5538494487029
# 3            False                       False          0.0  613.6371503273834
# 4            False                       False        19.99  553.5307904178921
# 5            False                       False        59.99  547.9275836296863
# ...            ...                         ...          ...                ...
# 4979         False                       False         0.99                0.0
# 4980         False                       False         2.99                0.0
# 4981         False                       False         4.99                0.0
# 4982         False                       False         8.99                0.0
# 4983         False                       False         4.99                0.0
#
# [4983 rows x 20 columns]

# %%
df.sort_values(by = 'score',ascending=False)
# Out:
#                                ResponseName ReleaseDate Metacritic  \
# 1          Counter-Strike: Global Offensive        2012         83
# 1857                             Brawlhalla        2014          0
# 1858                         ORION: Prelude        2013          0
# 1859              Batman(tm): Arkham Knight        2015          0
# 1860                          Geometry Dash        2014          0
# ...                                     ...         ...        ...
# 4889                                hackmud        2016          0
# 4888  Red Comrades 2: For the Great Justice        2016          0
# 4887           The Treasures of Montezuma 5        2016          0
# 4886                            Tokyo Babel        2016          0
# 4983                              The Tribe        2016          0
#
#      RecommendationCount IsFree GenreIsNonGame GenreIsIndie GenreIsAction  \
# 1                1427633  False          False        False          True
# 1857               27890   True          False         True          True
# 1858               27713   True          False         True          True
# 1859               27235  False          False        False          True
# 1860               27117  False          False         True          True
# ...                  ...    ...            ...          ...           ...
# 4889                   0  False          False         True         False
# 4888                   0  False          False        False         False
# 4887                   0  False          False        False         False
# 4886                   0  False          False        False         False
# 4983                   0  False          False         True          True
#
#      GenreIsAdventure GenreIsCasual GenreIsStrategy GenreIsRPG  \
# 1               False         False           False      False
# 1857            False         False           False      False
# 1858             True         False           False      False
# 1859             True         False           False      False
# 1860            False         False           False      False
# ...               ...           ...             ...        ...
# 4889            False         False           False       True
# 4888             True          True           False      False
# 4887            False          True           False      False
# 4886             True         False           False      False
# 4983             True         False           False      False
#
#      GenreIsSimulation GenreIsEarlyAccess GenreIsFreeToPlay GenreIsSports  \
# 1                False              False             False         False
# 1857             False               True              True         False
# 1858             False              False              True         False
# 1859             False              False             False         False
# 1860             False              False             False         False
# ...                ...                ...               ...           ...
# 4889              True              False             False         False
# 4888             False              False             False         False
# 4887             False              False             False         False
# 4886             False              False             False         False
# 4983             False              False             False         False
#
#      GenreIsRacing GenreIsMassivelyMultiplayer PriceInitial              score
# 1            False                       False        14.99  932.2916666666667
# 1857         False                       False          0.0  9.767916544378002
# 1858         False                       False          0.0  9.705925822672913
# 1859         False                       False        29.99  9.538515851062563
# 1860         False                       False         3.99  9.497188703259171
# ...            ...                         ...          ...                ...
# 4889         False                        True          0.0                0.0
# 4888         False                       False          0.0                0.0
# 4887         False                       False         6.99                0.0
# 4886         False                       False        34.99                0.0
# 4983         False                       False         4.99                0.0
#
# [4983 rows x 20 columns]

# %%
year_rank = df.groupby('ReleaseDate')[[
 'ResponseName',
 'score'
 ]].sum().sort_values(by='score',ascending=False)
year_rank
# Out:
#                                                   ResponseName  \
# ReleaseDate
# 2012         Counter-Strike: Global OffensiveBorderlands 2D...
# 2013         Dota 2BioShock InfinitePAYDAY 2System Shock 2D...
# 2007         Team Fortress 2BioShock(tm)QUAKECompany of Her...
# 2011         The Elder Scrolls V: SkyrimPortal 2Portal 2Por...
# 2015         Grand Theft Auto VThe Witcher(r) 3: Wild HuntU...
# 2009         Left 4 Dead 2The Elder Scrolls IV: Oblivion(r)...
# 2004         Half-Life 2Unreal Tournament 2004: Editors Cho...
# 1998                                                 Half-Life
# 2010         Sid Meiers Civilization(r) VSid Meiers Civiliz...
# 2016         Sid Meiers Civilization(r) VIOut of the Park B...
# 2006         Sid Meiers Civilization(r) IVSid Meiers Civili...
# 2000                                    Counter-StrikeRicochet
# 2008         Grand Theft Auto IVUnreal Tournament: Game of ...
# 2014         Freespace 2Rise of Nations: Extended EditionDi...
# 2005         Sid Meiers Pirates!DarwiniaDungeon Siege IIHal...
# 2001         Gothic 1Half-Life: Blue ShiftDeathmatch Classi...
# 2003                           Day of DefeatChicken Shoot Gold
# 1999            Half-Life: Opposing ForceTeam Fortress Classic
# 1997                                      Carmageddon Max Pack
# 2017                   Conan ExilesQuantum ReplicaTraiteurBUCK
# TBA          Rick and Morty Simulator: Virtual Rick-alitySe...
# Coming Soon                                      Fable Fortune
#
#                                                          score
# ReleaseDate
# 2012         932.2916666666667493.7882356378238482.86433368...
# 2013         675.5538494487029509.02530476436635488.4259433...
# 2007         613.6371503273834505.694740875281490.026724597...
# 2011         553.5307904178921520.4088946237116520.40329094...
# 2015         547.9275836296863502.00032807801443500.2904428...
# 2009         512.8281429529391492.3123260086217479.59744964...
# 2004         512.5354345269408484.8366032271599477.22159102...
# 1998                                        504.37297260570466
# 2010         498.79623737333054498.78222817068536492.127054...
# 2016         492.1053400395386479.2657817753816472.94324256...
# 2006         489.89433763205716489.893987401991489.89398740...
# 2000                      482.496055825738550.6882020799463168
# 2008         481.36248514148946479.5659289420554476.7710309...
# 2014         474.0154208341126464.64208953444853456.9943417...
# 2005         458.90806087185337437.65550214936195416.854389...
# 2001         422.3894879671456370.56882718341010.3110042987...
# 2003                      412.27051685668980.06199072170508808
# 1999                      1.02757501402671410.8542111312921458
# 1997                                        0.0844054459374363
# 2017                                              0.00.00.00.0
# TBA                                                     0.00.0
# Coming Soon                                                0.0

# %%
year_2012 = []
year_2013 = []
year_2007 = []
year_2011 = []
year_2015 = []
year_2009 = []
year_2004 = []
year_1998 = []
year_2010 = []
year_2016 = []
year_2006 = []
year_2000 = []
year_2008 = []
year_2014 = []
year_2005 = []
year_2001 = []
year_2003 = []
year_1999 = []
year_1997 = []
year_2017 = []

# %%
data
# Out:
# [{'number': '',
#   'ResponseName': 'ResponseName',
#   'ReleaseDate': 'ReleaseDate',
#   'Metacritic': 'Metacritic',
#   'RecommendationCount': 'RecommendationCount',
#   'IsFree': 'IsFree',
#   'GenreIsNonGame': 'GenreIsNonGame',
#   'GenreIsIndie': 'GenreIsIndie',
#   'GenreIsAction': 'GenreIsAction',
#   'GenreIsAdventure': 'GenreIsAdventure',
#   'GenreIsCasual': 'GenreIsCasual',
#   'GenreIsStrategy': 'GenreIsStrategy',
#   'GenreIsRPG': 'GenreIsRPG',
#   'GenreIsSimulation': 'GenreIsSimulation',
#   'GenreIsEarlyAccess': 'GenreIsEarlyAccess',
#   'GenreIsFreeToPlay': 'GenreIsFreeToPlay',
#   'GenreIsSports': 'GenreIsSports',
#   'GenreIsRacing': 'GenreIsRacing',
#   'GenreIsMassivelyMultiplayer': 'GenreIsMassivelyMultiplayer',
#   'PriceInitial': 'PriceInitial',
#   'score': 'score'},
#  {'number': '27',
#   'ResponseName': 'Counter-Strike: Global Offensive',
#   'ReleaseDate': 2012,
#   'Metacritic': '83',
#   'RecommendationCount': '1427633',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '932.2916666666667'},
#  {'number': '23',
#   'ResponseName': 'Dota 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '590480',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '675.5538494487029'},
#  {'number': '20',
#   'ResponseName': 'Team Fortress 2',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '383949',
#   'IsFree': 'True',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'True',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '613.6371503273834'},
#  {'number': '1365',
#   'ResponseName': 'The Elder Scrolls V: Skyrim',
#   'ReleaseDate': 2011,
#   'Metacritic': '94',
#   'RecommendationCount': '182587',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '553.5307904178921'},
#  {'number': '3088',
#   'ResponseName': 'Grand Theft Auto V',
#   'ReleaseDate': 2015,
#   'Metacritic': '96',
#   'RecommendationCount': '136846',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '547.9275836296863'},
#  {'number': '928',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73144',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4088946237116'},
#  {'number': '26',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '24',
#   'ResponseName': 'Portal 2',
#   'ReleaseDate': 2011,
#   'Metacritic': '95',
#   'RecommendationCount': '73128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '520.4032909426536'},
#  {'number': '22',
#   'ResponseName': 'Left 4 Dead 2',
#   'ReleaseDate': 2009,
#   'Metacritic': '89',
#   'RecommendationCount': '140726',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '512.8281429529391'},
#  {'number': '10',
#   'ResponseName': 'Half-Life 2',
#   'ReleaseDate': 2004,
#   'Metacritic': '96',
#   'RecommendationCount': '35792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '512.5354345269408'},
#  {'number': '273',
#   'ResponseName': 'BioShock Infinite',
#   'ReleaseDate': 2013,
#   'Metacritic': '94',
#   'RecommendationCount': '55512',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '509.02530476436635'},
#  {'number': '232',
#   'ResponseName': 'BioShock(tm)',
#   'ReleaseDate': 2007,
#   'Metacritic': '96',
#   'RecommendationCount': '16260',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '505.694740875281'},
#  {'number': '6',
#   'ResponseName': 'Half-Life',
#   'ReleaseDate': 1998,
#   'Metacritic': '96',
#   'RecommendationCount': '12486',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '504.37297260570466'},
#  {'number': '3612',
#   'ResponseName': 'The Witcher(r) 3: Wild Hunt',
#   'ReleaseDate': 2015,
#   'Metacritic': '93',
#   'RecommendationCount': '50325',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '502.00032807801443'},
#  {'number': '7292',
#   'ResponseName': 'Undertale',
#   'ReleaseDate': 2015,
#   'Metacritic': '92',
#   'RecommendationCount': '60314',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '500.2904428752581'},
#  {'number': '1205',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 2010,
#   'Metacritic': '90',
#   'RecommendationCount': '85790',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.79623737333054'},
#  {'number': '276',
#   'ResponseName': 'Sid Meiers Civilization(r) V',
#   'ReleaseDate': 2010,
#   'Metacritic': '90',
#   'RecommendationCount': '85750',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '498.78222817068536'},
#  {'number': '1198',
#   'ResponseName': 'Borderlands 2',
#   'ReleaseDate': 2012,
#   'Metacritic': '89',
#   'RecommendationCount': '86362',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '493.7882356378238'},
#  {'number': '579',
#   'ResponseName': 'The Elder Scrolls IV: Oblivion(r) Game of the Year Edition',
#   'ReleaseDate': 2009,
#   'Metacritic': '94',
#   'RecommendationCount': '7792',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '492.3123260086217'},
#  {'number': '631',
#   'ResponseName': 'Mass Effect 2',
#   'ReleaseDate': 2010,
#   'Metacritic': '94',
#   'RecommendationCount': '7263',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '492.1270543036387'},
#  {'number': '12040',
#   'ResponseName': 'Sid Meiers Civilization(r) VI',
#   'ReleaseDate': 2016,
#   'Metacritic': '94',
#   'RecommendationCount': '7201',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '492.1053400395386'},
#  {'number': '358',
#   'ResponseName': 'Grand Theft Auto: Vice City',
#   'ReleaseDate': 2011,
#   'Metacritic': '94',
#   'RecommendationCount': '4866',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '491.287552835124'},
#  {'number': '6602',
#   'ResponseName': 'Divinity: Original Sin - Enhanced Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '94',
#   'RecommendationCount': '2900',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '490.5990005251116'},
#  {'number': '57',
#   'ResponseName': 'QUAKE',
#   'ReleaseDate': 2007,
#   'Metacritic': '94',
#   'RecommendationCount': '1266',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '490.02672459705445'},
#  {'number': '962',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '888',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.89433763205716'},
#  {'number': '824',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '144',
#   'ResponseName': 'Sid Meiers Civilization(r) IV',
#   'ReleaseDate': 2006,
#   'Metacritic': '94',
#   'RecommendationCount': '887',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '489.893987401991'},
#  {'number': '359',
#   'ResponseName': 'Grand Theft Auto: San Andreas',
#   'ReleaseDate': 2011,
#   'Metacritic': '93',
#   'RecommendationCount': '14209',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '489.3514190096475'},
#  {'number': '1904',
#   'ResponseName': 'PAYDAY 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '79',
#   'RecommendationCount': '219763',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '488.4259433563575'},
#  {'number': '164',
#   'ResponseName': 'Company of Heroes',
#   'ReleaseDate': 2007,
#   'Metacritic': '93',
#   'RecommendationCount': '3856',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '485.72548713499896'},
#  {'number': '357',
#   'ResponseName': 'Grand Theft Auto III',
#   'ReleaseDate': 2011,
#   'Metacritic': '93',
#   'RecommendationCount': '2768',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '485.3444368230491'},
#  {'number': '411',
#   'ResponseName': 'Unreal Tournament 2004: Editors Choice Edition',
#   'ReleaseDate': 2004,
#   'Metacritic': '93',
#   'RecommendationCount': '1318',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '484.8366032271599'},
#  {'number': '3479',
#   'ResponseName': 'METAL GEAR SOLID V: THE PHANTOM PAIN',
#   'ReleaseDate': 2015,
#   'Metacritic': '91',
#   'RecommendationCount': '26956',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '483.3991349959455'},
#  {'number': '1637',
#   'ResponseName': 'Dishonored',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '25429',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.86433368496427'},
#  {'number': '0',
#   'ResponseName': 'Counter-Strike',
#   'ReleaseDate': 2000,
#   'Metacritic': '88',
#   'RecommendationCount': '68991',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '482.49605582573855'},
#  {'number': '367',
#   'ResponseName': 'Grand Theft Auto IV',
#   'ReleaseDate': 2008,
#   'Metacritic': '90',
#   'RecommendationCount': '36012',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.36248514148946'},
#  {'number': '239',
#   'ResponseName': 'Call of Duty(r) 4: Modern Warfare(r)',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '5983',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '481.2620931523251'},
#  {'number': '1477',
#   'ResponseName': 'Terraria',
#   'ReleaseDate': 2011,
#   'Metacritic': '83',
#   'RecommendationCount': '139819',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '481.2604842829588'},
#  {'number': '169',
#   'ResponseName': 'Rome: Total War(tm) - Collection',
#   'ReleaseDate': 2007,
#   'Metacritic': '92',
#   'RecommendationCount': '5160',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.97385380789973'},
#  {'number': '2265',
#   'ResponseName': 'System Shock 2',
#   'ReleaseDate': 2013,
#   'Metacritic': '92',
#   'RecommendationCount': '3216',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '480.2930065593422'},
#  {'number': '1541',
#   'ResponseName': 'Batman: Arkham City - Game of the Year Edition',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '16418',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.7084105590629'},
#  {'number': '419',
#   'ResponseName': 'Tom Clancys Splinter Cell Chaos Theory(r)',
#   'ReleaseDate': 2009,
#   'Metacritic': '92',
#   'RecommendationCount': '1230',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5974496480071'},
#  {'number': '412',
#   'ResponseName': 'Unreal Tournament: Game of the Year Edition',
#   'ReleaseDate': 2008,
#   'Metacritic': '92',
#   'RecommendationCount': '1140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '479.5659289420554'},
#  {'number': '1785',
#   'ResponseName': 'Thief(tm) Gold',
#   'ReleaseDate': 2012,
#   'Metacritic': '92',
#   'RecommendationCount': '1116',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '6.99',
#   'score': '479.55752342046827'},
#  {'number': '1579',
#   'ResponseName': 'Galactic Civilizations(r) II: Ultimate Edition',
#   'ReleaseDate': 2011,
#   'Metacritic': '92',
#   'RecommendationCount': '827',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.45630693135655'},
#  {'number': '584',
#   'ResponseName': 'Fallout 3: Game of the Year Edition',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '15420',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '479.3588809530647'},
#  {'number': '7677',
#   'ResponseName': 'Out of the Park Baseball 17',
#   'ReleaseDate': 2016,
#   'Metacritic': '92',
#   'RecommendationCount': '283',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '479.2657817753816'},
#  {'number': '966',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13358',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63670655670376'},
#  {'number': '841',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '844',
#   'ResponseName': 'Batman: Arkham Asylum Game of the Year Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '13356',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.63600609657146'},
#  {'number': '1227',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '27546',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.39743740162913'},
#  {'number': '18',
#   'ResponseName': 'Portal',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '27535',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '478.3935848709017'},
#  {'number': '2593',
#   'ResponseName': 'Rocket League(r)',
#   'ReleaseDate': 2015,
#   'Metacritic': '86',
#   'RecommendationCount': '86627',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'True',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '478.25604660534844'},
#  {'number': '1835',
#   'ResponseName': 'Mark of the Ninja',
#   'ReleaseDate': 2012,
#   'Metacritic': '91',
#   'RecommendationCount': '11059',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '477.83152763466984'},
#  {'number': '11',
#   'ResponseName': 'Counter-Strike: Source',
#   'ReleaseDate': 2004,
#   'Metacritic': '88',
#   'RecommendationCount': '53931',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.22159102981414'},
#  {'number': '2261',
#   'ResponseName': 'Deus Ex: Human Revolution - Directors Cut',
#   'ReleaseDate': 2013,
#   'Metacritic': '91',
#   'RecommendationCount': '8724',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '477.01374043025527'},
#  {'number': '2018',
#   'ResponseName': 'FEZ',
#   'ReleaseDate': 2013,
#   'Metacritic': '91',
#   'RecommendationCount': '8516',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.9408925765001'},
#  {'number': '576',
#   'ResponseName': 'Fallout 3',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '8031',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '476.7710309944269'},
#  {'number': '2028',
#   'ResponseName': 'Brothers - A Tale of Two Sons',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '22471',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '476.62001981601713'},
#  {'number': '1171',
#   'ResponseName': 'Dragon Age: Origins - Ultimate Edition',
#   'ReleaseDate': 2010,
#   'Metacritic': '91',
#   'RecommendationCount': '6848',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '476.35670882619456'},
#  {'number': '495',
#   'ResponseName': 'Dragon Age: Origins',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '4146',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.4103871875101'},
#  {'number': '488',
#   'ResponseName': 'Crysis',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '3881',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '475.31757621998554'},
#  {'number': '1546',
#   'ResponseName': 'XCOM: Enemy Unknown',
#   'ReleaseDate': 2012,
#   'Metacritic': '89',
#   'RecommendationCount': '31794',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '29.99',
#   'score': '474.67688138921795'},
#  {'number': '78',
#   'ResponseName': 'Call of Duty(r)',
#   'ReleaseDate': 2006,
#   'Metacritic': '91',
#   'RecommendationCount': '851',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.2563791196103'},
#  {'number': '196',
#   'ResponseName': 'The Longest Journey',
#   'ReleaseDate': 2007,
#   'Metacritic': '91',
#   'RecommendationCount': '737',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.2164528920714'},
#  {'number': '720',
#   'ResponseName': 'STAR WARS(tm) Jedi Knight: Dark Forces II',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '735',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '5.99',
#   'score': '474.2157524319392'},
#  {'number': '418',
#   'ResponseName': 'Tom Clancys Splinter Cell(r)',
#   'ReleaseDate': 2008,
#   'Metacritic': '91',
#   'RecommendationCount': '586',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.16356815208576'},
#  {'number': '561',
#   'ResponseName': 'Street Fighter(r) IV',
#   'ReleaseDate': 2009,
#   'Metacritic': '91',
#   'RecommendationCount': '343',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '474.0784622460161'},
#  {'number': '3119',
#   'ResponseName': 'Freespace 2',
#   'ReleaseDate': 2014,
#   'Metacritic': '91',
#   'RecommendationCount': '163',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '474.0154208341126'},
#  {'number': '6640',
#   'ResponseName': 'DARK SOULS(tm) III',
#   'ReleaseDate': 2016,
#   'Metacritic': '89',
#   'RecommendationCount': '26844',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '59.99',
#   'score': '472.94324256187224'},
#  {'number': '327',
#   'ResponseName': 'Empire: Total War(tm)',
#   'ReleaseDate': 2009,
#   'Metacritic': '90',
#   'RecommendationCount': '11234',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '472.6844845629094'},
#  {'number': '1934',
#   'ResponseName': 'Far Cry 3',
#   'ReleaseDate': 2012,
#   'Metacritic': '88',
#   'RecommendationCount': '36011',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '470.9454682447566'},
#  {'number': '19',
#   'ResponseName': 'Half-Life 2: Episode Two',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '6104',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '470.88780432366025'},
#  {'number': '2290',
#   'ResponseName': 'Spelunky',
#   'ReleaseDate': 2013,
#   'Metacritic': '90',
#   'RecommendationCount': '6079',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.879048572007'},
#  {'number': '651',
#   'ResponseName': 'Braid',
#   'ReleaseDate': 2009,
#   'Metacritic': '90',
#   'RecommendationCount': '5069',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '470.5253162052152'},
#  {'number': '212',
#   'ResponseName': 'Deus Ex: Game of the Year Edition',
#   'ReleaseDate': 2007,
#   'Metacritic': '90',
#   'RecommendationCount': '3706',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '6.99',
#   'score': '470.0479526250794'},
#  {'number': '568',
#   'ResponseName': 'World of Goo',
#   'ReleaseDate': 2008,
#   'Metacritic': '90',
#   'RecommendationCount': '2685',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
# ...
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.54730248133336'},
#  {'number': '1765',
#   'ResponseName': 'Unmechanical',
#   'ReleaseDate': 2012,
#   'Metacritic': '74',
#   'RecommendationCount': '317',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52768959763'},
#  {'number': '8377',
#   'ResponseName': 'Project Highrise',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '315',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52698913749776'},
#  {'number': '2669',
#   'ResponseName': 'Shadows: Heretic Kingdoms',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '306',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.52383706690256'},
#  {'number': '2108',
#   'ResponseName': 'Incredipede',
#   'ReleaseDate': 2013,
#   'Metacritic': '74',
#   'RecommendationCount': '301',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.52208591657194'},
#  {'number': '4709',
#   'ResponseName': 'Annas Quest',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '299',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.5213854564397'},
#  {'number': '3426',
#   'ResponseName': 'Action Henk',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '295',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'True',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5199845361751'},
#  {'number': '7390',
#   'ResponseName': 'Warhammer 40000: Deathwatch - Enhanced Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '277',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.5136803949848'},
#  {'number': '3669',
#   'ResponseName': 'TRI: Of Friendship and Madness',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '232',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.49792004200896'},
#  {'number': '220',
#   'ResponseName': 'Runaway A Road Adventure',
#   'ReleaseDate': 2007,
#   'Metacritic': '74',
#   'RecommendationCount': '212',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.49091544068636'},
#  {'number': '1614',
#   'ResponseName': 'Snapshot',
#   'ReleaseDate': 2012,
#   'Metacritic': '74',
#   'RecommendationCount': '202',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '385.48741314002507'},
#  {'number': '3145',
#   'ResponseName': 'Drox Operative',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '185',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4814592289008'},
#  {'number': '84',
#   'ResponseName': 'ARMA: Combat Operations',
#   'ReleaseDate': 2008,
#   'Metacritic': '74',
#   'RecommendationCount': '181',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.4800583086363'},
#  {'number': '8526',
#   'ResponseName': 'Neon Chrome',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '165',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.4744546275782'},
#  {'number': '3571',
#   'ResponseName': 'Cloud Chamber',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '141',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'True',
#   'PriceInitial': '19.99',
#   'score': '385.4660491059911'},
#  {'number': '3801',
#   'ResponseName': 'Space Colony: Steam Edition',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '140',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '385.46569887592494'},
#  {'number': '175',
#   'ResponseName': 'Cossacks: European Wars',
#   'ReleaseDate': 2011,
#   'Metacritic': '74',
#   'RecommendationCount': '135',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '385.46394772559427'},
#  {'number': '2391',
#   'ResponseName': 'Where is my Heart?',
#   'ReleaseDate': 2014,
#   'Metacritic': '74',
#   'RecommendationCount': '128',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '7.99',
#   'score': '385.46149611513135'},
#  {'number': '7250',
#   'ResponseName': 'Sora',
#   'ReleaseDate': 2016,
#   'Metacritic': '74',
#   'RecommendationCount': '124',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '8.99',
#   'score': '385.4600951948668'},
#  {'number': '4151',
#   'ResponseName': 'Crookz - The Big Heist',
#   'ReleaseDate': 2015,
#   'Metacritic': '74',
#   'RecommendationCount': '103',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'True',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '385.4527403634781'},
#  {'number': '2640',
#   'ResponseName': 'Shadow Warrior',
#   'ReleaseDate': 2013,
#   'Metacritic': '73',
#   'RecommendationCount': '10697',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '39.99',
#   'score': '383.9547443507306'},
#  {'number': '3223',
#   'ResponseName': 'A Story About My Uncle',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '6675',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'True',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '12.99',
#   'score': '382.546119024754'},
#  {'number': '2920',
#   'ResponseName': 'Lords Of The Fallen(tm)',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '6584',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '19.99',
#   'score': '382.5142480887361'},
#  {'number': '1063',
#   'ResponseName': 'War of the Roses',
#   'ReleaseDate': 2013,
#   'Metacritic': '73',
#   'RecommendationCount': '4417',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'True',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '0.0',
#   'score': '381.75529953543145'},
#  {'number': '3496',
#   'ResponseName': 'The Room',
#   'ReleaseDate': 2014,
#   'Metacritic': '73',
#   'RecommendationCount': '4054',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'True',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'False',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '4.99',
#   'score': '381.6281660214261'},
#  {'number': '7385',
#   'ResponseName': 'Punch Club',
#   'ReleaseDate': 2016,
#   'Metacritic': '73',
#   'RecommendationCount': '3664',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'True',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'True',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '9.99',
#   'score': '381.49157629563524'},
#  {'number': '1537',
#   'ResponseName': 'Worms Revolution',
#   'ReleaseDate': 2012,
#   'Metacritic': '73',
#   'RecommendationCount': '3320',
#   'IsFree': 'False',
#   'GenreIsNonGame': 'False',
#   'GenreIsIndie': 'False',
#   'GenreIsAction': 'False',
#   'GenreIsAdventure': 'False',
#   'GenreIsCasual': 'False',
#   'GenreIsStrategy': 'True',
#   'GenreIsRPG': 'False',
#   'GenreIsSimulation': 'False',
#   'GenreIsEarlyAccess': 'False',
#   'GenreIsFreeToPlay': 'False',
#   'GenreIsSports': 'False',
#   'GenreIsRacing': 'False',
#   'GenreIsMassivelyMultiplayer': 'False',
#   'PriceInitial': '14.99',
#   'score': '381.37109715288636'},
#  ...]

# %%
for i in data:
    if i['ReleaseDate']== 2012:
        year_2012.append(i['ResponseName'])
    elif i['ReleaseDate']== 2013:
        year_2013.append(i['ResponseName'])
    elif i['ReleaseDate']== 2007:
        year_2007.append(i['ResponseName'])
    elif i['ReleaseDate']== 2011:
        year_2011.append(i['ResponseName'])
    elif i['ReleaseDate']== 2015:
        year_2015.append(i['ResponseName'])
    elif i['ReleaseDate']== 2009:
        year_2009.append(i['ResponseName'])
    elif i['ReleaseDate']== 2004:
        year_2004.append(i['ResponseName'])
    elif i['ReleaseDate']== 1998:
        year_1998.append(i['ResponseName'])
    elif i['ReleaseDate']== 2010:
        year_2010.append(i['ResponseName'])
    elif i['ReleaseDate']== 2016:
        year_2016.append(i['ResponseName'])
    elif i['ReleaseDate']== 2006:
        year_2006.append(i['ResponseName'])
    elif i['ReleaseDate']== 2000:
        year_2000.append(i['ResponseName'])
    elif i['ReleaseDate']== 2008:
        year_2008.append(i['ResponseName'])
    elif i['ReleaseDate']== 2014:
        year_2014.append(i['ResponseName'])
    elif i['ReleaseDate']== 2005:
        year_2005.append(i['ResponseName'])
    elif i['ReleaseDate']== 2001:
        year_2001.append(i['ResponseName'])
    elif i['ReleaseDate']== 2003:
        year_2003.append(i['ResponseName'])
    elif i['ReleaseDate']== 1999:
        year_1999.append(i['ResponseName'])
    elif i['ReleaseDate']== 1997:
        year_1997.append(i['ResponseName'])
    elif i['ReleaseDate']== 2017:
        year_2017.append(i['ResponseName'])

# %%
year_2012
# Out:
# ['Counter-Strike: Global Offensive',
#  'Borderlands 2',
#  'Dishonored',
#  'Batman: Arkham City - Game of the Year Edition',
#  'Thief(tm) Gold',
#  'Mark of the Ninja',
#  'XCOM: Enemy Unknown',
#  'Far Cry 3',
#  'NBA 2K13',
#  'The Witcher 2: Assassins of Kings Enhanced Edition',
#  'Torchlight II',
#  'Super Hexagon',
#  'Max Payne 3',
#  'DARK SOULS(tm): Prepare To Die(tm) Edition',
#  'Thirty Flights of Loving',
#  'Hotline Miami',
#  'Thief(tm) II: The Metal Age',
#  'Tribes: Ascend',
#  'The Lord of the Rings Online',
#  'The Lord of the Rings Online',
#  'PlanetSide 2',
#  'FTL: Faster Than Light',
#  'Rayman(r) Origins',
#  'Total War: Shogun 2 - Fall of the Samurai',
#  'STAR WARS(tm) Knights of the Old Republic(tm) II - The Sith Lords(tm)',
#  'Unity of Command: Stalingrad Campaign',
#  'GT Legends',
#  'Alan Wake',
#  'The Walking Dead',
#  'Orcs Must Die! 2',
#  'Realm of the Mad God',
#  'Crusader Kings II',
#  'Tales From Space: Mutant Blobs Attack',
#  'To the Moon',
#  'Sins of a Solar Empire(r): Rebellion',
#  'Legend of Grimrock',
#  'Botanicula',
#  'The Book of Unwritten Tales',
#  'Chivalry: Medieval Warfare',
#  'Age of Empires(r) III: Complete Collection',
#  'Kingdoms of Amalur: Reckoning(tm)',
#  'Wargame: European Escalation',
#  'Waveform',
#  'Lone Survivor: The Directors Cut',
#  'Divine Divinity',
#  'Wizorb',
#  'PixelJunk(tm) Eden',
#  'Vessel',
#  'Assassins Creed(r) III',
#  'Natural Selection 2',
#  'Natural Selection 2',
#  'Natural Selection 2',
#  'Hitman: Absolution(tm)',
#  'LEGO The Lord of the Rings',
#  'Stacking',
#  'F1 2012(tm)',
#  'Intrusion 2',
#  'Stealth Bastard Deluxe',
#  'The Blackwell Legacy',
#  'Noitu Love 2: Devolution',
#  'FlyN',
#  'LEGO Harry Potter: Years 5-7',
#  'Awesomenauts',
#  'Dustforce DX',
#  'Street Fighter X Tekken',
#  'Waking Mars',
#  'Offspring Fling!',
#  'Deadlight',
#  'Condemned: Criminal Origins',
#  'Chaos on Deponia',
#  'Rocksmith(tm)',
#  'Closure',
#  'Fallen Enchantress',
#  'Thomas Was Alone',
#  'The Darkness II',
#  'Endless Space(r) - Emperor Edition',
#  'Spec Ops: The Line',
#  'Giana Sisters: Twisted Dreams',
#  'Quantum Conundrum',
#  'Magic: The Gathering - Duels of the Planeswalkers 2013',
#  'Sine Mora',
#  'The Dream Machine: Chapter 1 & 2',
#  'Legacy of Kain: Soul Reaver 2',
#  'Star Trek Online',
#  'Super MNC',
#  'Prototype 2',
#  'Vindictus',
#  'McPixel',
#  'Ys Origin',
#  'Miasmata',
#  'Insanely Twisted Shadow Planet',
#  'Avernum: Escape From the Pit',
#  'Resonance',
#  'Dins Curse',
#  'Blacklight: Retribution',
#  'Call of Duty(r): Black Ops II',
#  'Call of Duty(r): Black Ops II',
#  'Stronghold Kingdoms',
#  'Scribblenauts Unlimited',
#  'Dear Esther',
#  'Tiny and Big: Grandpas Leftovers',
#  'Symphony',
#  'Half Minute Hero: Super Mega Neo Climax Ultimate Boy',
#  'Edna & Harvey: Harveys New Eyes',
#  'The Dark Eye: Chains of Satinav',
#  'Hero Academy',
#  'Iron Brigade',
#  'Deponia',
#  'Serious Sam 2',
#  'The Secret World',
#  'They Bleed Pixels',
#  'Rocketbirds: Hardboiled Chicken',
#  'Kings Bounty: Warriors of the North',
#  'Stellar Impact',
#  'Cubemen',
#  'Unmechanical',
#  'Snapshot',
#  'Worms Revolution',
#  'Alan Wakes American Nightmare',
#  'Hard Reset Extended Edition',
#  'The Testament of Sherlock Holmes',
#  'Ys: The Oath in Felghana',
#  'Blackwell Deception',
#  'The Book of Unwritten Tales: The Critter Chronicles',
#  'Unstoppable Gorg',
#  'Beyond Divinity',
#  'DiRT Showdown',
#  'Shank 2',
#  'Primordia',
#  'A New Beginning - Final Cut',
#  'Ridge Racer(tm) Unbounded',
#  'Gateways',
#  'Fallen Earth Free2Play',
#  'Tom Clancys Ghost Recon: Future Soldier(tm)',
#  'Warlock - Master of the Arcane',
#  'Toy Soldiers',
#  'Splice',
#  'Evochron Mercenary',
#  'Legacy of Kain: Defiance',
#  'Risen 2: Dark Waters',
#  'Home',
#  'Of Orcs And Men',
#  'Little Inferno',
#  'Binary Domain',
#  'Sniper Elite V2',
#  'Primal Carnage',
#  'Oil Rush',
#  'I Am Alive',
#  'King Arthur II: The Role-Playing Wargame',
#  'Sword of the Stars II: Enhanced Edition',
#  'A Virus Named TOM',
#  'Choplifter HD',
#  'Guns of Icarus Online',
#  'Hell Yeah! Wrath of the Dead Rabbit',
#  'Painkiller Hell & Damnation',
#  'Naval War: Arctic Circle',
#  'Pid',
#  'Blades of Time',
#  'Jagged Alliance: Crossfire',
#  'Analogue: A Hate Story',
#  'Jagged Alliance - Back in Action',
#  'F1 RACE STARS(tm)',
#  'Pineapple Smash Crew',
#  'Dream Pinball 3D',
#  'POSTAL 2',
#  'A Game of Dwarves',
#  'Lucius',
#  'Tower Wars',
#  'Fireburst',
#  'Game of Thrones',
#  'Tiny Troopers',
#  'Men of War: Condemned Heroes',
#  'Conflict Desert Storm(tm)',
#  'Iron Front: Digital War Edition',
#  'SpellForce 2: Faith in Destiny',
#  'Sonic the Hedgehog 4 - Episode II',
#  'A Valley Without Wind',
#  'Nexuiz',
#  'Gemini Wars',
#  'Krater',
#  'Miner Wars 2081',
#  'Confrontation',
#  'Resident Evil: Operation Raccoon City',
#  'Karateka',
#  'Cortex Command',
#  'Deep Black: Reloaded',
#  'Painkiller: Recurring Evil',
#  'Postal III',
#  'Gettysburg: Armored Warfare',
#  'Castle Crashers(r)',
#  'Infestation: Survivor Stories Classic',
#  'Ace of Spades: Battle Builder',
#  'Source Filmmaker',
#  'Gotham City Impostors Free to Play',
#  'AirMech(r)',
#  'Super Crate Box',
#  'MicroVolts Surge',
#  'MapleStory',
#  'RPG Maker VX Ace',
#  'Sonic Adventure 2',
#  'Doom 3: BFG Edition',
#  'Jet Set Radio',
#  'GameMaker: Studio',
#  'Stronghold 3 Gold',
#  'Defenders Quest: Valley of the Forgotten (DX edition)',
#  'Transformers(tm): Fall of Cybertron(tm)',
#  'Towns',
#  'Dead Pixels',
#  'Mabinogi',
#  'Really Big Sky',
#  'Superbrothers: Sword & Sworcery EP',
#  'Indie Game: The Movie',
#  'Dragon Nest',
#  'Dwarfs - F2P',
#  'Dungeons & Dragons Online(r)',
#  'Zombie Driver HD',
#  'Tony Hawks Pro Skater(r) HD',
#  'The Amazing Spider-Man(tm)',
#  'Viking: Battle for Asgard',
#  'You Need a Budget 4',
#  'Sonic CD',
#  'Divinity II: Developers Cut',
#  'Tomb Raider I',
#  'Blood Bowl: Chaos Edition',
#  'Galaxy on Fire 2(tm) Full HD',
#  'Frontline Tactics',
#  'Continent of the Ninth Seal',
#  'Adventures of Shuggy',
#  'Sacred 2 Gold',
#  'Ticket to Ride',
#  'Sonic the Hedgehog 4 - Episode I',
#  'Fairy Bloom Freesia',
#  'Kung Fu Strike - The Warriors Rise',
#  'The Basement Collection',
#  'Titan Attacks!',
#  'Magical Diary: Horse Hall',
#  'Cargo Commander',
#  'Carrier Command: Gaea Mission',
#  'Hack Slash Loot',
#  'Shoot Many Robots',
#  'LEGO(r) Batman 2 DC Super Heroes(tm)',
#  'Legacy of Kain: Soul Reaver',
#  'Sea Dogs: To Each His Own',
#  'Cherry Tree High Comedy Club',
#  'Fortune Summoners',
#  'Everquest (r)',
#  'Triple Town',
#  'Penny Arcades On the Rain-Slick Precipice of Darkness 3',
#  'Tomb Raider II',
#  'R.A.W. Realms of Ancient War',
#  'Wanderlust: Rebirth',
#  'Planets Under Attack',
#  'Death Rally',
#  'iBomber Defense Pacific',
#  'eXceed 3rd - Jade Penetrate Black Package',
#  'Moon Breakers',
#  'Port Royale 3',
#  'Lunar Flight',
#  'Yesterday',
#  'eXceed - Gun Bullet Children',
#  'NiGHTS Into Dreams',
#  'Snuggle Truck',
#  'Iron Sky: Invasion',
#  'Puddle',
#  'Rune Classic',
#  'Arena Wars 2',
#  'Inversion(tm)',
#  'Dynamite Jack',
#  'ROSE Online',
#  'Magical Drop V',
#  'Dogfight 1942',
#  'Jagged Alliance 2 - Wildfire',
#  'Hamlet or the Last Game without MMORPG Features Shaders ...',
#  'Air Conflicts: Pacific Carriers',
#  'Tomb Raider III',
#  'Doctor Who: The Eternity Clock',
#  'Tomb Raider VI: The Angel of Darkness',
#  'Janes Advanced Strike Fighters',
#  'Bang Bang Racing',
#  'English Country Tune',
#  'Monopoly',
#  'War of the Immortals',
#  'Foreign Legion: Multi Massacre',
#  'Conquest of Elysium 3',
#  'Insane 2',
#  'Blackwell Unbound',
#  'Revelations 2012',
#  'New Star Soccer 5',
#  'Tomb Raider IV: The Last Revelation',
#  'Test Drive: Ferrari Racing Legends',
#  '1000 Amps',
#  'Containment: The Zombie Puzzler',
#  'Warp',
#  'Critter Crunch',
#  'ETHER VAPOR Remaster',
#  'Blackwell Convergence',
#  'eXceed 2nd - Vampire REX',
#  'Fowl Space',
#  'Call of Duty: Black Ops - Mac Edition',
#  'Auditorium',
#  'Sugar Cube: Bittersweet Factory',
#  '3SwitcheD',
#  'Fieldrunners',
#  'Party of Sin',
#  'Sherlock Holmes and The Hound of The Baskervilles',
#  'Spirits',
#  'Tomb Raider V: Chronicles',
#  'Luxor Evolved',
#  'GTR 2 FIA GT Racing Game',
#  'iBomber Attack',
#  'CameraBag 2',
#  'Storm in a Teacup',
#  'Dead Hungry Diner',
#  'Atlantica Online',
#  '7 Wonders: Ancient Alien Makeover',
#  'Scoregasm',
#  'Aerofly FS 1 Flight Simulator',
#  'Pickers']

# %%
 
IsFree_2012_count = 0
GenreIsNonGame_2012_count = 0
GenreIsIndie_2012_count = 0
GenreIsAction_2012_count = 0
GenreIsAdventure_2012_count = 0
GenreIsCasual_2012_count = 0
GenreIsStrategy_2012_count = 0
GenreIsRPG_2012_count = 0
GenreIsSimulation_2012_count = 0
GenreIsEarlyAccess_2012_count = 0
GenreIsFreeToPlay_2012_count = 0
GenreIsSports_2012_count = 0
GenreIsRacing_2012_count = 0
GenreIsMassivelyMultiplayer_2012_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2012:
        IsFree_2012_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsNonGame_2012_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsIndie_2012_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsAction_2012_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsAdventure_2012_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsCasual_2012_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsStrategy_2012_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsRPG_2012_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsSimulation_2012_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsEarlyAccess_2012_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsFreeToPlay_2012_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsSports_2012_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsRacing_2012_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2012:
        GenreIsMassivelyMultiplayer_2012_count += 1

# %%
IsFree_2013_count = 0
GenreIsNonGame_2013_count = 0
GenreIsIndie_2013_count = 0
GenreIsAction_2013_count = 0
GenreIsAdventure_2013_count = 0
GenreIsCasual_2013_count = 0
GenreIsStrategy_2013_count = 0
GenreIsRPG_2013_count = 0
GenreIsSimulation_2013_count = 0
GenreIsEarlyAccess_2013_count = 0
GenreIsFreeToPlay_2013_count = 0
GenreIsSports_2013_count = 0
GenreIsRacing_2013_count = 0
GenreIsMassivelyMultiplayer_2013_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2013:
        IsFree_2013_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsNonGame_2013_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsIndie_2013_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsAction_2013_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsAdventure_2013_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsCasual_2013_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsStrategy_2013_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsRPG_2013_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsSimulation_2013_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsEarlyAccess_2013_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsFreeToPlay_2013_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsSports_2013_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsRacing_2013_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2013:
        GenreIsMassivelyMultiplayer_2013_count += 1

# %%
IsFree_2007_count = 0
GenreIsNonGame_2007_count = 0
GenreIsIndie_2007_count = 0
GenreIsAction_2007_count = 0
GenreIsAdventure_2007_count = 0
GenreIsCasual_2007_count = 0
GenreIsStrategy_2007_count = 0
GenreIsRPG_2007_count = 0
GenreIsSimulation_2007_count = 0
GenreIsEarlyAccess_2007_count = 0
GenreIsFreeToPlay_2007_count = 0
GenreIsSports_2007_count = 0
GenreIsRacing_2007_count = 0
GenreIsMassivelyMultiplayer_2007_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2007:
        IsFree_2007_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsNonGame_2007_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsIndie_2007_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsAction_2007_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsAdventure_2007_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsCasual_2007_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsStrategy_2007_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsRPG_2007_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsSimulation_2007_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsEarlyAccess_2007_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsFreeToPlay_2007_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsSports_2007_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsRacing_2007_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2007:
        GenreIsMassivelyMultiplayer_2007_count += 1

# %%
IsFree_2011_count = 0
GenreIsNonGame_2011_count = 0
GenreIsIndie_2011_count = 0
GenreIsAction_2011_count = 0
GenreIsAdventure_2011_count = 0
GenreIsCasual_2011_count = 0
GenreIsStrategy_2011_count = 0
GenreIsRPG_2011_count = 0
GenreIsSimulation_2011_count = 0
GenreIsEarlyAccess_2011_count = 0
GenreIsFreeToPlay_2011_count = 0
GenreIsSports_2011_count = 0
GenreIsRacing_2011_count = 0
GenreIsMassivelyMultiplayer_2011_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2011:
        IsFree_2011_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsNonGame_2011_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsIndie_2011_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsAction_2011_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsAdventure_2011_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsCasual_2011_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsStrategy_2011_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsRPG_2011_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsSimulation_2011_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsEarlyAccess_2011_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsFreeToPlay_2011_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsSports_2011_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsRacing_2011_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2011:
        GenreIsMassivelyMultiplayer_2011_count += 1

# %%
IsFree_2015_count = 0
GenreIsNonGame_2015_count = 0
GenreIsIndie_2015_count = 0
GenreIsAction_2015_count = 0
GenreIsAdventure_2015_count = 0
GenreIsCasual_2015_count = 0
GenreIsStrategy_2015_count = 0
GenreIsRPG_2015_count = 0
GenreIsSimulation_2015_count = 0
GenreIsEarlyAccess_2015_count = 0
GenreIsFreeToPlay_2015_count = 0
GenreIsSports_2015_count = 0
GenreIsRacing_2015_count = 0
GenreIsMassivelyMultiplayer_2015_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2015:
        IsFree_2015_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsNonGame_2015_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsIndie_2015_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsAction_2015_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsAdventure_2015_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsCasual_2015_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsStrategy_2015_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsRPG_2015_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsSimulation_2015_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsEarlyAccess_2015_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsFreeToPlay_2015_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsSports_2015_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsRacing_2015_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2015:
        GenreIsMassivelyMultiplayer_2015_count += 1

# %%
IsFree_2009_count = 0
GenreIsNonGame_2009_count = 0
GenreIsIndie_2009_count = 0
GenreIsAction_2009_count = 0
GenreIsAdventure_2009_count = 0
GenreIsCasual_2009_count = 0
GenreIsStrategy_2009_count = 0
GenreIsRPG_2009_count = 0
GenreIsSimulation_2009_count = 0
GenreIsEarlyAccess_2009_count = 0
GenreIsFreeToPlay_2009_count = 0
GenreIsSports_2009_count = 0
GenreIsRacing_2009_count = 0
GenreIsMassivelyMultiplayer_2009_count = 0

# %%
for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2009:
        IsFree_2009_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsNonGame_2009_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsIndie_2009_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsAction_2009_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsAdventure_2009_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsCasual_2009_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsStrategy_2009_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsRPG_2009_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsSimulation_2009_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsEarlyAccess_2009_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsFreeToPlay_2009_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsSports_2009_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsRacing_2009_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2009:
        GenreIsMassivelyMultiplayer_2009_count += 1

# %%
IsFree_2004_count = 0
GenreIsNonGame_2004_count = 0
GenreIsIndie_2004_count = 0
GenreIsAction_2004_count = 0
GenreIsAdventure_2004_count = 0
GenreIsCasual_2004_count = 0
GenreIsStrategy_2004_count = 0
GenreIsRPG_2004_count = 0
GenreIsSimulation_2004_count = 0
GenreIsEarlyAccess_2004_count = 0
GenreIsFreeToPlay_2004_count = 0
GenreIsSports_2004_count = 0
GenreIsRacing_2004_count = 0
GenreIsMassivelyMultiplayer_2004_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2004:
        IsFree_2004_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsNonGame_2004_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsIndie_2004_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsAction_2004_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsAdventure_2004_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsCasual_2004_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsStrategy_2004_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsRPG_2004_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsSimulation_2004_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsEarlyAccess_2004_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsFreeToPlay_2004_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsSports_2004_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsRacing_2004_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2004:
        GenreIsMassivelyMultiplayer_2004_count += 1

# %%
IsFree_1998_count = 0
GenreIsNonGame_1998_count = 0
GenreIsIndie_1998_count = 0
GenreIsAction_1998_count = 0
GenreIsAdventure_1998_count = 0
GenreIsCasual_1998_count = 0
GenreIsStrategy_1998_count = 0
GenreIsRPG_1998_count = 0
GenreIsSimulation_1998_count = 0
GenreIsEarlyAccess_1998_count = 0
GenreIsFreeToPlay_1998_count = 0
GenreIsSports_1998_count = 0
GenreIsRacing_1998_count = 0
GenreIsMassivelyMultiplayer_1998_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 1998:
        IsFree_1998_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsNonGame_1998_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsIndie_1998_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsAction_1998_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsAdventure_1998_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsCasual_1998_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsStrategy_1998_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsRPG_1998_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsSimulation_1998_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsEarlyAccess_1998_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsFreeToPlay_1998_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsSports_1998_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsRacing_1998_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 1998:
        GenreIsMassivelyMultiplayer_1998_count += 1

# %%
IsFree_2010_count = 0
GenreIsNonGame_2010_count = 0
GenreIsIndie_2010_count = 0
GenreIsAction_2010_count = 0
GenreIsAdventure_2010_count = 0
GenreIsCasual_2010_count = 0
GenreIsStrategy_2010_count = 0
GenreIsRPG_2010_count = 0
GenreIsSimulation_2010_count = 0
GenreIsEarlyAccess_2010_count = 0
GenreIsFreeToPlay_2010_count = 0
GenreIsSports_2010_count = 0
GenreIsRacing_2010_count = 0
GenreIsMassivelyMultiplayer_2010_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2010:
        IsFree_2010_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsNonGame_2010_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsIndie_2010_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsAction_2010_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsAdventure_2010_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsCasual_2010_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsStrategy_2010_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsRPG_2010_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsSimulation_2010_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsEarlyAccess_2010_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsFreeToPlay_2010_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsSports_2010_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsRacing_2010_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2010:
        GenreIsMassivelyMultiplayer_2010_count += 1

# %%
IsFree_2016_count = 0
GenreIsNonGame_2016_count = 0
GenreIsIndie_2016_count = 0
GenreIsAction_2016_count = 0
GenreIsAdventure_2016_count = 0
GenreIsCasual_2016_count = 0
GenreIsStrategy_2016_count = 0
GenreIsRPG_2016_count = 0
GenreIsSimulation_2016_count = 0
GenreIsEarlyAccess_2016_count = 0
GenreIsFreeToPlay_2016_count = 0
GenreIsSports_2016_count = 0
GenreIsRacing_2016_count = 0
GenreIsMassivelyMultiplayer_2016_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2016:
        IsFree_2016_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsNonGame_2016_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsIndie_2016_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsAction_2016_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsAdventure_2016_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsCasual_2016_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsStrategy_2016_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsRPG_2016_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsSimulation_2016_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsEarlyAccess_2016_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsFreeToPlay_2016_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsSports_2016_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsRacing_2016_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2016:
        GenreIsMassivelyMultiplayer_2016_count += 1

# %%
IsFree_2006_count = 0
GenreIsNonGame_2006_count = 0
GenreIsIndie_2006_count = 0
GenreIsAction_2006_count = 0
GenreIsAdventure_2006_count = 0
GenreIsCasual_2006_count = 0
GenreIsStrategy_2006_count = 0
GenreIsRPG_2006_count = 0
GenreIsSimulation_2006_count = 0
GenreIsEarlyAccess_2006_count = 0
GenreIsFreeToPlay_2006_count = 0
GenreIsSports_2006_count = 0
GenreIsRacing_2006_count = 0
GenreIsMassivelyMultiplayer_2006_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2006:
        IsFree_2006_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsNonGame_2006_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsIndie_2006_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsAction_2006_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsAdventure_2006_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsCasual_2006_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsStrategy_2006_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsRPG_2006_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsSimulation_2006_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsEarlyAccess_2006_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsFreeToPlay_2006_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsSports_2006_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsRacing_2006_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2006:
        GenreIsMassivelyMultiplayer_2006_count += 1

# %%
IsFree_2000_count = 0
GenreIsNonGame_2000_count = 0
GenreIsIndie_2000_count = 0
GenreIsAction_2000_count = 0
GenreIsAdventure_2000_count = 0
GenreIsCasual_2000_count = 0
GenreIsStrategy_2000_count = 0
GenreIsRPG_2000_count = 0
GenreIsSimulation_2000_count = 0
GenreIsEarlyAccess_2000_count = 0
GenreIsFreeToPlay_2000_count = 0
GenreIsSports_2000_count = 0
GenreIsRacing_2000_count = 0
GenreIsMassivelyMultiplayer_2000_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2000:
        IsFree_2000_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsNonGame_2000_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsIndie_2000_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsAction_2000_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsAdventure_2000_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsCasual_2000_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsStrategy_2000_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsRPG_2000_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsSimulation_2000_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsEarlyAccess_2000_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsFreeToPlay_2000_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsSports_2000_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsRacing_2000_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2000:
        GenreIsMassivelyMultiplayer_2000_count += 1

# %%
IsFree_2008_count = 0
GenreIsNonGame_2008_count = 0
GenreIsIndie_2008_count = 0
GenreIsAction_2008_count = 0
GenreIsAdventure_2008_count = 0
GenreIsCasual_2008_count = 0
GenreIsStrategy_2008_count = 0
GenreIsRPG_2008_count = 0
GenreIsSimulation_2008_count = 0
GenreIsEarlyAccess_2008_count = 0
GenreIsFreeToPlay_2008_count = 0
GenreIsSports_2008_count = 0
GenreIsRacing_2008_count = 0
GenreIsMassivelyMultiplayer_2008_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2008:
        IsFree_2008_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsNonGame_2008_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsIndie_2008_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsAction_2008_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsAdventure_2008_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsCasual_2008_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsStrategy_2008_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsRPG_2008_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsSimulation_2008_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsEarlyAccess_2008_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsFreeToPlay_2008_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsSports_2008_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsRacing_2008_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2008:
        GenreIsMassivelyMultiplayer_2008_count += 1

# %%
IsFree_2014_count = 0
GenreIsNonGame_2014_count = 0
GenreIsIndie_2014_count = 0
GenreIsAction_2014_count = 0
GenreIsAdventure_2014_count = 0
GenreIsCasual_2014_count = 0
GenreIsStrategy_2014_count = 0
GenreIsRPG_2014_count = 0
GenreIsSimulation_2014_count = 0
GenreIsEarlyAccess_2014_count = 0
GenreIsFreeToPlay_2014_count = 0
GenreIsSports_2014_count = 0
GenreIsRacing_2014_count = 0
GenreIsMassivelyMultiplayer_2014_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2014:
        IsFree_2014_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsNonGame_2014_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsIndie_2014_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsAction_2014_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsAdventure_2014_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsCasual_2014_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsStrategy_2014_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsRPG_2014_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsSimulation_2014_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsEarlyAccess_2014_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsFreeToPlay_2014_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsSports_2014_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsRacing_2014_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2014:
        GenreIsMassivelyMultiplayer_2014_count += 1

# %%
IsFree_2005_count = 0
GenreIsNonGame_2005_count = 0
GenreIsIndie_2005_count = 0
GenreIsAction_2005_count = 0
GenreIsAdventure_2005_count = 0
GenreIsCasual_2005_count = 0
GenreIsStrategy_2005_count = 0
GenreIsRPG_2005_count = 0
GenreIsSimulation_2005_count = 0
GenreIsEarlyAccess_2005_count = 0
GenreIsFreeToPlay_2005_count = 0
GenreIsSports_2005_count = 0
GenreIsRacing_2005_count = 0
GenreIsMassivelyMultiplayer_2005_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2005:
        IsFree_2005_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsNonGame_2005_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsIndie_2005_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsAction_2005_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsAdventure_2005_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsCasual_2005_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsStrategy_2005_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsRPG_2005_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsSimulation_2005_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsEarlyAccess_2005_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsFreeToPlay_2005_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsSports_2005_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsRacing_2005_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2005:
        GenreIsMassivelyMultiplayer_2005_count += 1

# %%
IsFree_2001_count = 0
GenreIsNonGame_2001_count = 0
GenreIsIndie_2001_count = 0
GenreIsAction_2001_count = 0
GenreIsAdventure_2001_count = 0
GenreIsCasual_2001_count = 0
GenreIsStrategy_2001_count = 0
GenreIsRPG_2001_count = 0
GenreIsSimulation_2001_count = 0
GenreIsEarlyAccess_2001_count = 0
GenreIsFreeToPlay_2001_count = 0
GenreIsSports_2001_count = 0
GenreIsRacing_2001_count = 0
GenreIsMassivelyMultiplayer_2001_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2001:
        IsFree_2001_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsNonGame_2001_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsIndie_2001_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsAction_2001_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsAdventure_2001_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsCasual_2001_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsStrategy_2001_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsRPG_2001_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsSimulation_2001_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsEarlyAccess_2001_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsFreeToPlay_2001_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsSports_2001_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsRacing_2001_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2001:
        GenreIsMassivelyMultiplayer_2001_count += 1

# %%
IsFree_2003_count = 0
GenreIsNonGame_2003_count = 0
GenreIsIndie_2003_count = 0
GenreIsAction_2003_count = 0
GenreIsAdventure_2003_count = 0
GenreIsCasual_2003_count = 0
GenreIsStrategy_2003_count = 0
GenreIsRPG_2003_count = 0
GenreIsSimulation_2003_count = 0
GenreIsEarlyAccess_2003_count = 0
GenreIsFreeToPlay_2003_count = 0
GenreIsSports_2003_count = 0
GenreIsRacing_2003_count = 0
GenreIsMassivelyMultiplayer_2003_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2003:
        IsFree_2003_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsNonGame_2003_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsIndie_2003_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsAction_2003_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsAdventure_2003_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsCasual_2003_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsStrategy_2003_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsRPG_2003_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsSimulation_2003_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsEarlyAccess_2003_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsFreeToPlay_2003_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsSports_2003_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsRacing_2003_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2003:
        GenreIsMassivelyMultiplayer_2003_count += 1

# %%
IsFree_1999_count = 0
GenreIsNonGame_1999_count = 0
GenreIsIndie_1999_count = 0
GenreIsAction_1999_count = 0
GenreIsAdventure_1999_count = 0
GenreIsCasual_1999_count = 0
GenreIsStrategy_1999_count = 0
GenreIsRPG_1999_count = 0
GenreIsSimulation_1999_count = 0
GenreIsEarlyAccess_1999_count = 0
GenreIsFreeToPlay_1999_count = 0
GenreIsSports_1999_count = 0
GenreIsRacing_1999_count = 0
GenreIsMassivelyMultiplayer_1999_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 1999:
        IsFree_1999_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsNonGame_1999_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsIndie_1999_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsAction_1999_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsAdventure_1999_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsCasual_1999_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsStrategy_1999_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsRPG_1999_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsSimulation_1999_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsEarlyAccess_1999_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsFreeToPlay_1999_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsSports_1999_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsRacing_1999_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 1999:
        GenreIsMassivelyMultiplayer_1999_count += 1

# %%
IsFree_1997_count = 0
GenreIsNonGame_1997_count = 0
GenreIsIndie_1997_count = 0
GenreIsAction_1997_count = 0
GenreIsAdventure_1997_count = 0
GenreIsCasual_1997_count = 0
GenreIsStrategy_1997_count = 0
GenreIsRPG_1997_count = 0
GenreIsSimulation_1997_count = 0
GenreIsEarlyAccess_1997_count = 0
GenreIsFreeToPlay_1997_count = 0
GenreIsSports_1997_count = 0
GenreIsRacing_1997_count = 0
GenreIsMassivelyMultiplayer_1997_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 1997:
        IsFree_1997_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsNonGame_1997_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsIndie_1997_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsAction_1997_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsAdventure_1997_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsCasual_1997_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsStrategy_1997_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsRPG_1997_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsSimulation_1997_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsEarlyAccess_1997_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsFreeToPlay_1997_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsSports_1997_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsRacing_1997_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 1997:
        GenreIsMassivelyMultiplayer_1997_count += 1

# %%
IsFree_2017_count = 0
GenreIsNonGame_2017_count = 0
GenreIsIndie_2017_count = 0
GenreIsAction_2017_count = 0
GenreIsAdventure_2017_count = 0
GenreIsCasual_2017_count = 0
GenreIsStrategy_2017_count = 0
GenreIsRPG_2017_count = 0
GenreIsSimulation_2017_count = 0
GenreIsEarlyAccess_2017_count = 0
GenreIsFreeToPlay_2017_count = 0
GenreIsSports_2017_count = 0
GenreIsRacing_2017_count = 0
GenreIsMassivelyMultiplayer_2017_count = 0

for i in data:
    if i['IsFree'] == 'True' and i['ReleaseDate'] == 2017:
        IsFree_2017_count += 1
    if i['GenreIsNonGame'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsNonGame_2017_count += 1
    if i['GenreIsIndie'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsIndie_2017_count += 1
    if i['GenreIsAction'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsAction_2017_count += 1
    if i['GenreIsAdventure'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsAdventure_2017_count += 1
    if i['GenreIsCasual'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsCasual_2017_count += 1
    if i['GenreIsStrategy'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsStrategy_2017_count += 1
    if i['GenreIsRPG'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsRPG_2017_count += 1
    if i['GenreIsSimulation'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsSimulation_2017_count += 1
    if i['GenreIsEarlyAccess'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsEarlyAccess_2017_count += 1
    if i['GenreIsFreeToPlay'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsFreeToPlay_2017_count += 1
    if i['GenreIsSports'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsSports_2017_count += 1 
    if i['GenreIsRacing'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsRacing_2017_count += 1 
    if i['GenreIsMassivelyMultiplayer'] == 'True' and i['ReleaseDate'] == 2017:
        GenreIsMassivelyMultiplayer_2017_count += 1

# %%
IsFree_2017_count
# Out:
# 0

# %%
year_rank['IsFree_count'] = [
    IsFree_2012_count,
    IsFree_2013_count,
    IsFree_2007_count,
    IsFree_2011_count,
    IsFree_2015_count,
    IsFree_2009_count,
    IsFree_2004_count,
    IsFree_1998_count,
    IsFree_2010_count,
    IsFree_2016_count,
    IsFree_2006_count,
    IsFree_2000_count,
    IsFree_2008_count,
    IsFree_2014_count,
    IsFree_2005_count,
    IsFree_2001_count,
    IsFree_2003_count,
    IsFree_1999_count,
    IsFree_1997_count,
    IsFree_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsNonGame_count'] = [
    GenreIsNonGame_2012_count,
    GenreIsNonGame_2013_count,
    GenreIsNonGame_2007_count,
    GenreIsNonGame_2011_count,
    GenreIsNonGame_2015_count,
    GenreIsNonGame_2009_count,
    GenreIsNonGame_2004_count,
    GenreIsNonGame_1998_count,
    GenreIsNonGame_2010_count,
    GenreIsNonGame_2016_count,
    GenreIsNonGame_2006_count,
    GenreIsNonGame_2000_count,
    GenreIsNonGame_2008_count,
    GenreIsNonGame_2014_count,
    GenreIsNonGame_2005_count,
    GenreIsNonGame_2001_count,
    GenreIsNonGame_2003_count,
    GenreIsNonGame_1999_count,
    GenreIsNonGame_1997_count,
    GenreIsNonGame_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsIndie_count'] = [
    GenreIsIndie_2012_count,
    GenreIsIndie_2013_count,
    GenreIsIndie_2007_count,
    GenreIsIndie_2011_count,
    GenreIsIndie_2015_count,
    GenreIsIndie_2009_count,
    GenreIsIndie_2004_count,
    GenreIsIndie_1998_count,
    GenreIsIndie_2010_count,
    GenreIsIndie_2016_count,
    GenreIsIndie_2006_count,
    GenreIsIndie_2000_count,
    GenreIsIndie_2008_count,
    GenreIsIndie_2014_count,
    GenreIsIndie_2005_count,
    GenreIsIndie_2001_count,
    GenreIsIndie_2003_count,
    GenreIsIndie_1999_count,
    GenreIsIndie_1997_count,
    GenreIsIndie_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsAction_count'] = [
    GenreIsAction_2012_count,
    GenreIsAction_2013_count,
    GenreIsAction_2007_count,
    GenreIsAction_2011_count,
    GenreIsAction_2015_count,
    GenreIsAction_2009_count,
    GenreIsAction_2004_count,
    GenreIsAction_1998_count,
    GenreIsAction_2010_count,
    GenreIsAction_2016_count,
    GenreIsAction_2006_count,
    GenreIsAction_2000_count,
    GenreIsAction_2008_count,
    GenreIsAction_2014_count,
    GenreIsAction_2005_count,
    GenreIsAction_2001_count,
    GenreIsAction_2003_count,
    GenreIsAction_1999_count,
    GenreIsAction_1997_count,
    GenreIsAction_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsAdventure_count'] = [
    GenreIsAdventure_2012_count,
    GenreIsAdventure_2013_count,
    GenreIsAdventure_2007_count,
    GenreIsAdventure_2011_count,
    GenreIsAdventure_2015_count,
    GenreIsAdventure_2009_count,
    GenreIsAdventure_2004_count,
    GenreIsAdventure_1998_count,
    GenreIsAdventure_2010_count,
    GenreIsAdventure_2016_count,
    GenreIsAdventure_2006_count,
    GenreIsAdventure_2000_count,
    GenreIsAdventure_2008_count,
    GenreIsAdventure_2014_count,
    GenreIsAdventure_2005_count,
    GenreIsAdventure_2001_count,
    GenreIsAdventure_2003_count,
    GenreIsAdventure_1999_count,
    GenreIsAdventure_1997_count,
    GenreIsAdventure_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsCasual_count'] = [
    GenreIsCasual_2012_count,
    GenreIsCasual_2013_count,
    GenreIsCasual_2007_count,
    GenreIsCasual_2011_count,
    GenreIsCasual_2015_count,
    GenreIsCasual_2009_count,
    GenreIsCasual_2004_count,
    GenreIsCasual_1998_count,
    GenreIsCasual_2010_count,
    GenreIsCasual_2016_count,
    GenreIsCasual_2006_count,
    GenreIsCasual_2000_count,
    GenreIsCasual_2008_count,
    GenreIsCasual_2014_count,
    GenreIsCasual_2005_count,
    GenreIsCasual_2001_count,
    GenreIsCasual_2003_count,
    GenreIsCasual_1999_count,
    GenreIsCasual_1997_count,
    GenreIsCasual_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsStrategy_count'] = [
    GenreIsStrategy_2012_count,
    GenreIsStrategy_2013_count,
    GenreIsStrategy_2007_count,
    GenreIsStrategy_2011_count,
    GenreIsStrategy_2015_count,
    GenreIsStrategy_2009_count,
    GenreIsStrategy_2004_count,
    GenreIsStrategy_1998_count,
    GenreIsStrategy_2010_count,
    GenreIsStrategy_2016_count,
    GenreIsStrategy_2006_count,
    GenreIsStrategy_2000_count,
    GenreIsStrategy_2008_count,
    GenreIsStrategy_2014_count,
    GenreIsStrategy_2005_count,
    GenreIsStrategy_2001_count,
    GenreIsStrategy_2003_count,
    GenreIsStrategy_1999_count,
    GenreIsStrategy_1997_count,
    GenreIsStrategy_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsRPG_count'] = [
    GenreIsRPG_2012_count,
    GenreIsRPG_2013_count,
    GenreIsRPG_2007_count,
    GenreIsRPG_2011_count,
    GenreIsRPG_2015_count,
    GenreIsRPG_2009_count,
    GenreIsRPG_2004_count,
    GenreIsRPG_1998_count,
    GenreIsRPG_2010_count,
    GenreIsRPG_2016_count,
    GenreIsRPG_2006_count,
    GenreIsRPG_2000_count,
    GenreIsRPG_2008_count,
    GenreIsRPG_2014_count,
    GenreIsRPG_2005_count,
    GenreIsRPG_2001_count,
    GenreIsRPG_2003_count,
    GenreIsRPG_1999_count,
    GenreIsRPG_1997_count,
    GenreIsRPG_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsSimulation_count'] = [
    GenreIsSimulation_2012_count,
    GenreIsSimulation_2013_count,
    GenreIsSimulation_2007_count,
    GenreIsSimulation_2011_count,
    GenreIsSimulation_2015_count,
    GenreIsSimulation_2009_count,
    GenreIsSimulation_2004_count,
    GenreIsSimulation_1998_count,
    GenreIsSimulation_2010_count,
    GenreIsSimulation_2016_count,
    GenreIsSimulation_2006_count,
    GenreIsSimulation_2000_count,
    GenreIsSimulation_2008_count,
    GenreIsSimulation_2014_count,
    GenreIsSimulation_2005_count,
    GenreIsSimulation_2001_count,
    GenreIsSimulation_2003_count,
    GenreIsSimulation_1999_count,
    GenreIsSimulation_1997_count,
    GenreIsSimulation_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsEarlyAccess_count'] = [
    GenreIsEarlyAccess_2012_count,
    GenreIsEarlyAccess_2013_count,
    GenreIsEarlyAccess_2007_count,
    GenreIsEarlyAccess_2011_count,
    GenreIsEarlyAccess_2015_count,
    GenreIsEarlyAccess_2009_count,
    GenreIsEarlyAccess_2004_count,
    GenreIsEarlyAccess_1998_count,
    GenreIsEarlyAccess_2010_count,
    GenreIsEarlyAccess_2016_count,
    GenreIsEarlyAccess_2006_count,
    GenreIsEarlyAccess_2000_count,
    GenreIsEarlyAccess_2008_count,
    GenreIsEarlyAccess_2014_count,
    GenreIsEarlyAccess_2005_count,
    GenreIsEarlyAccess_2001_count,
    GenreIsEarlyAccess_2003_count,
    GenreIsEarlyAccess_1999_count,
    GenreIsEarlyAccess_1997_count,
    GenreIsEarlyAccess_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsFreeToPlay_count'] = [
    GenreIsFreeToPlay_2012_count,
    GenreIsFreeToPlay_2013_count,
    GenreIsFreeToPlay_2007_count,
    GenreIsFreeToPlay_2011_count,
    GenreIsFreeToPlay_2015_count,
    GenreIsFreeToPlay_2009_count,
    GenreIsFreeToPlay_2004_count,
    GenreIsFreeToPlay_1998_count,
    GenreIsFreeToPlay_2010_count,
    GenreIsFreeToPlay_2016_count,
    GenreIsFreeToPlay_2006_count,
    GenreIsFreeToPlay_2000_count,
    GenreIsFreeToPlay_2008_count,
    GenreIsFreeToPlay_2014_count,
    GenreIsFreeToPlay_2005_count,
    GenreIsFreeToPlay_2001_count,
    GenreIsFreeToPlay_2003_count,
    GenreIsFreeToPlay_1999_count,
    GenreIsFreeToPlay_1997_count,
    GenreIsFreeToPlay_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsSports_count'] = [
    GenreIsSports_2012_count,
    GenreIsSports_2013_count,
    GenreIsSports_2007_count,
    GenreIsSports_2011_count,
    GenreIsSports_2015_count,
    GenreIsSports_2009_count,
    GenreIsSports_2004_count,
    GenreIsSports_1998_count,
    GenreIsSports_2010_count,
    GenreIsSports_2016_count,
    GenreIsSports_2006_count,
    GenreIsSports_2000_count,
    GenreIsSports_2008_count,
    GenreIsSports_2014_count,
    GenreIsSports_2005_count,
    GenreIsSports_2001_count,
    GenreIsSports_2003_count,
    GenreIsSports_1999_count,
    GenreIsSports_1997_count,
    GenreIsSports_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsRacing_count'] = [
    GenreIsRacing_2012_count,
    GenreIsRacing_2013_count,
    GenreIsRacing_2007_count,
    GenreIsRacing_2011_count,
    GenreIsRacing_2015_count,
    GenreIsRacing_2009_count,
    GenreIsRacing_2004_count,
    GenreIsRacing_1998_count,
    GenreIsRacing_2010_count,
    GenreIsRacing_2016_count,
    GenreIsRacing_2006_count,
    GenreIsRacing_2000_count,
    GenreIsRacing_2008_count,
    GenreIsRacing_2014_count,
    GenreIsRacing_2005_count,
    GenreIsRacing_2001_count,
    GenreIsRacing_2003_count,
    GenreIsRacing_1999_count,
    GenreIsRacing_1997_count,
    GenreIsRacing_2017_count,
    0,
    0
    ]

# %%
year_rank['GenreIsMassivelyMultiplayer_count'] = [
    GenreIsMassivelyMultiplayer_2012_count,
    GenreIsMassivelyMultiplayer_2013_count,
    GenreIsMassivelyMultiplayer_2007_count,
    GenreIsMassivelyMultiplayer_2011_count,
    GenreIsMassivelyMultiplayer_2015_count,
    GenreIsMassivelyMultiplayer_2009_count,
    GenreIsMassivelyMultiplayer_2004_count,
    GenreIsMassivelyMultiplayer_1998_count,
    GenreIsMassivelyMultiplayer_2010_count,
    GenreIsMassivelyMultiplayer_2016_count,
    GenreIsMassivelyMultiplayer_2006_count,
    GenreIsMassivelyMultiplayer_2000_count,
    GenreIsMassivelyMultiplayer_2008_count,
    GenreIsMassivelyMultiplayer_2014_count,
    GenreIsMassivelyMultiplayer_2005_count,
    GenreIsMassivelyMultiplayer_2001_count,
    GenreIsMassivelyMultiplayer_2003_count,
    GenreIsMassivelyMultiplayer_1999_count,
    GenreIsMassivelyMultiplayer_1997_count,
    GenreIsMassivelyMultiplayer_2017_count,
    0,
    0
    ]

# %%
year_rank['game_number'] = [
    len(year_2012),
    len(year_2013),
    len(year_2007),
    len(year_2011),
    len(year_2015),
    len(year_2009),
    len(year_2004),
    len(year_1998),
    len(year_2010),
    len(year_2016),
    len(year_2006),
    len(year_2000),
    len(year_2008),
    len(year_2014),
    len(year_2005),
    len(year_2001),
    len(year_2003),
    len(year_1999),
    len(year_1997),
    len(year_2017),
    0,
    0
    ]

# %%
year_rank
# Out:
#                                                   ResponseName  \
# ReleaseDate
# 2012         Counter-Strike: Global OffensiveBorderlands 2D...
# 2013         Dota 2BioShock InfinitePAYDAY 2System Shock 2D...
# 2007         Team Fortress 2BioShock(tm)QUAKECompany of Her...
# 2011         The Elder Scrolls V: SkyrimPortal 2Portal 2Por...
# 2015         Grand Theft Auto VThe Witcher(r) 3: Wild HuntU...
# 2009         Left 4 Dead 2The Elder Scrolls IV: Oblivion(r)...
# 2004         Half-Life 2Unreal Tournament 2004: Editors Cho...
# 1998                                                 Half-Life
# 2010         Sid Meiers Civilization(r) VSid Meiers Civiliz...
# 2016         Sid Meiers Civilization(r) VIOut of the Park B...
# 2006         Sid Meiers Civilization(r) IVSid Meiers Civili...
# 2000                                    Counter-StrikeRicochet
# 2008         Grand Theft Auto IVUnreal Tournament: Game of ...
# 2014         Freespace 2Rise of Nations: Extended EditionDi...
# 2005         Sid Meiers Pirates!DarwiniaDungeon Siege IIHal...
# 2001         Gothic 1Half-Life: Blue ShiftDeathmatch Classi...
# 2003                           Day of DefeatChicken Shoot Gold
# 1999            Half-Life: Opposing ForceTeam Fortress Classic
# 1997                                      Carmageddon Max Pack
# 2017                   Conan ExilesQuantum ReplicaTraiteurBUCK
# TBA          Rick and Morty Simulator: Virtual Rick-alitySe...
# Coming Soon                                      Fable Fortune
#
#                                                          score  IsFree_count  \
# ReleaseDate
# 2012         932.2916666666667493.7882356378238482.86433368...            31
# 2013         675.5538494487029509.02530476436635488.4259433...            35
# 2007         613.6371503273834505.694740875281490.026724597...             5
# 2011         553.5307904178921520.4088946237116520.40329094...            16
# 2015         547.9275836296863502.00032807801443500.2904428...           189
# 2009         512.8281429529391492.3123260086217479.59744964...             7
# 2004         512.5354345269408484.8366032271599477.22159102...             1
# 1998                                        504.37297260570466             0
# 2010         498.79623737333054498.78222817068536492.127054...             3
# 2016         492.1053400395386479.2657817753816472.94324256...           195
# 2006         489.89433763205716489.893987401991489.89398740...             2
# 2000                      482.496055825738550.6882020799463168             0
# 2008         481.36248514148946479.5659289420554476.7710309...             3
# 2014         474.0154208341126464.64208953444853456.9943417...            89
# 2005         458.90806087185337437.65550214936195416.854389...             1
# 2001         422.3894879671456370.56882718341010.3110042987...             2
# 2003                      412.27051685668980.06199072170508808             0
# 1999                      1.02757501402671410.8542111312921458             0
# 1997                                        0.0844054459374363             0
# 2017                                              0.00.00.00.0             0
# TBA                                                     0.00.0             0
# Coming Soon                                                0.0             0
#
#              GenreIsNonGame_count  GenreIsIndie_count  GenreIsAction_count  \
# ReleaseDate
# 2012                            5                 155                  175
# 2013                            6                 224                  227
# 2007                            0                   8                   56
# 2011                            0                  83                  122
# 2015                           17                 878                  582
# 2009                            0                  46                   89
# 2004                            0                   0                    8
# 1998                            0                   0                    1
# 2010                            0                  54                   93
# 2016                           17                 727                  481
# 2006                            0                   5                   22
# 2000                            0                   0                    2
# 2008                            0                  14                   54
# 2014                           10                 669                  499
# 2005                            0                   1                    1
# 2001                            0                   1                    3
# 2003                            0                   1                    2
# 1999                            0                   0                    2
# 1997                            0                   1                    1
# 2017                            0                   3                    4
# TBA                             0                   0                    0
# Coming Soon                     0                   0                    0
#
#              GenreIsAdventure_count  GenreIsCasual_count  \
# ReleaseDate
# 2012                             98                   45
# 2013                            143                   58
# 2007                              9                    9
# 2011                             45                   35
# 2015                            475                  288
# 2009                             36                   23
# 2004                              0                    0
# 1998                              0                    0
# 2010                             41                   30
# 2016                            413                  280
# 2006                              0                    3
# 2000                              0                    0
# 2008                             20                    7
# 2014                            381                  229
# 2005                              0                    0
# 2001                              0                    0
# 2003                              0                    1
# 1999                              0                    0
# 1997                              0                    0
# 2017                              2                    0
# TBA                               0                    0
# Coming Soon                       0                    0
#
#              GenreIsStrategy_count  GenreIsRPG_count  GenreIsSimulation_count  \
# ReleaseDate
# 2012                            76                61                       33
# 2013                           102                83                       73
# 2007                            21                 9                        1
# 2011                            69                42                       26
# 2015                           303               273                      257
# 2009                            49                35                       21
# 2004                             0                 0                        0
# 1998                             0                 0                        0
# 2010                            47                31                       19
# 2016                           233               223                      230
# 2006                            16                 5                        1
# 2000                             0                 0                        0
# 2008                            19                 9                       11
# 2014                           229               239                      171
# 2005                             1                 2                        0
# 2001                             1                 2                        0
# 2003                             0                 0                        0
# 1999                             0                 0                        0
# 1997                             0                 0                        0
# 2017                             0                 2                        0
# TBA                              0                 0                        0
# Coming Soon                      0                 0                        0
#
#              GenreIsEarlyAccess_count  GenreIsFreeToPlay_count  \
# ReleaseDate
# 2012                                1                       27
# 2013                               17                       27
# 2007                                0                        1
# 2011                                0                       12
# 2015                              143                      169
# 2009                                0                        2
# 2004                                0                        0
# 1998                                0                        0
# 2010                                0                        1
# 2016                              155                      154
# 2006                                0                        0
# 2000                                0                        0
# 2008                                0                        1
# 2014                               75                       79
# 2005                                0                        0
# 2001                                0                        0
# 2003                                0                        0
# 1999                                0                        0
# 1997                                0                        0
# 2017                                2                        0
# TBA                                 0                        0
# Coming Soon                         0                        0
#
#              GenreIsSports_count  GenreIsRacing_count  \
# ReleaseDate
# 2012                           9                   13
# 2013                          17                   19
# 2007                           0                    3
# 2011                           6                   12
# 2015                          51                   44
# 2009                           5                    7
# 2004                           0                    0
# 1998                           0                    0
# 2010                           4                    7
# 2016                          59                   42
# 2006                           0                    5
# 2000                           0                    0
# 2008                           1                    9
# 2014                          35                   48
# 2005                           0                    0
# 2001                           0                    0
# 2003                           0                    0
# 1999                           0                    0
# 1997                           0                    1
# 2017                           0                    0
# TBA                            0                    0
# Coming Soon                    0                    0
#
#              GenreIsMassivelyMultiplayer_count  game_number
# ReleaseDate
# 2012                                        20          318
# 2013                                        15          421
# 2007                                         0           91
# 2011                                        10          237
# 2015                                        72         1242
# 2009                                         0          199
# 2004                                         0            8
# 1998                                         0            1
# 2010                                         1          192
# 2016                                        82         1067
# 2006                                         0           47
# 2000                                         0            2
# 2008                                         0          102
# 2014                                        45         1036
# 2005                                         0            4
# 2001                                         0            4
# 2003                                         0            2
# 1999                                         0            2
# 1997                                         0            1
# 2017                                         1            4
# TBA                                          0            0
# Coming Soon                                  0            0

# %%
year_rank.drop(year_rank.index[20:22],inplace = True)
year_rank
# Out:
#                                                   ResponseName  \
# ReleaseDate
# 2012         Counter-Strike: Global OffensiveBorderlands 2D...
# 2013         Dota 2BioShock InfinitePAYDAY 2System Shock 2D...
# 2007         Team Fortress 2BioShock(tm)QUAKECompany of Her...
# 2011         The Elder Scrolls V: SkyrimPortal 2Portal 2Por...
# 2015         Grand Theft Auto VThe Witcher(r) 3: Wild HuntU...
# 2009         Left 4 Dead 2The Elder Scrolls IV: Oblivion(r)...
# 2004         Half-Life 2Unreal Tournament 2004: Editors Cho...
# 1998                                                 Half-Life
# 2010         Sid Meiers Civilization(r) VSid Meiers Civiliz...
# 2016         Sid Meiers Civilization(r) VIOut of the Park B...
# 2006         Sid Meiers Civilization(r) IVSid Meiers Civili...
# 2000                                    Counter-StrikeRicochet
# 2008         Grand Theft Auto IVUnreal Tournament: Game of ...
# 2014         Freespace 2Rise of Nations: Extended EditionDi...
# 2005         Sid Meiers Pirates!DarwiniaDungeon Siege IIHal...
# 2001         Gothic 1Half-Life: Blue ShiftDeathmatch Classi...
# 2003                           Day of DefeatChicken Shoot Gold
# 1999            Half-Life: Opposing ForceTeam Fortress Classic
# 1997                                      Carmageddon Max Pack
# 2017                   Conan ExilesQuantum ReplicaTraiteurBUCK
#
#                                                          score  IsFree_count  \
# ReleaseDate
# 2012         932.2916666666667493.7882356378238482.86433368...            31
# 2013         675.5538494487029509.02530476436635488.4259433...            35
# 2007         613.6371503273834505.694740875281490.026724597...             5
# 2011         553.5307904178921520.4088946237116520.40329094...            16
# 2015         547.9275836296863502.00032807801443500.2904428...           189
# 2009         512.8281429529391492.3123260086217479.59744964...             7
# 2004         512.5354345269408484.8366032271599477.22159102...             1
# 1998                                        504.37297260570466             0
# 2010         498.79623737333054498.78222817068536492.127054...             3
# 2016         492.1053400395386479.2657817753816472.94324256...           195
# 2006         489.89433763205716489.893987401991489.89398740...             2
# 2000                      482.496055825738550.6882020799463168             0
# 2008         481.36248514148946479.5659289420554476.7710309...             3
# 2014         474.0154208341126464.64208953444853456.9943417...            89
# 2005         458.90806087185337437.65550214936195416.854389...             1
# 2001         422.3894879671456370.56882718341010.3110042987...             2
# 2003                      412.27051685668980.06199072170508808             0
# 1999                      1.02757501402671410.8542111312921458             0
# 1997                                        0.0844054459374363             0
# 2017                                              0.00.00.00.0             0
#
#              GenreIsNonGame_count  GenreIsIndie_count  GenreIsAction_count  \
# ReleaseDate
# 2012                            5                 155                  175
# 2013                            6                 224                  227
# 2007                            0                   8                   56
# 2011                            0                  83                  122
# 2015                           17                 878                  582
# 2009                            0                  46                   89
# 2004                            0                   0                    8
# 1998                            0                   0                    1
# 2010                            0                  54                   93
# 2016                           17                 727                  481
# 2006                            0                   5                   22
# 2000                            0                   0                    2
# 2008                            0                  14                   54
# 2014                           10                 669                  499
# 2005                            0                   1                    1
# 2001                            0                   1                    3
# 2003                            0                   1                    2
# 1999                            0                   0                    2
# 1997                            0                   1                    1
# 2017                            0                   3                    4
#
#              GenreIsAdventure_count  GenreIsCasual_count  \
# ReleaseDate
# 2012                             98                   45
# 2013                            143                   58
# 2007                              9                    9
# 2011                             45                   35
# 2015                            475                  288
# 2009                             36                   23
# 2004                              0                    0
# 1998                              0                    0
# 2010                             41                   30
# 2016                            413                  280
# 2006                              0                    3
# 2000                              0                    0
# 2008                             20                    7
# 2014                            381                  229
# 2005                              0                    0
# 2001                              0                    0
# 2003                              0                    1
# 1999                              0                    0
# 1997                              0                    0
# 2017                              2                    0
#
#              GenreIsStrategy_count  GenreIsRPG_count  GenreIsSimulation_count  \
# ReleaseDate
# 2012                            76                61                       33
# 2013                           102                83                       73
# 2007                            21                 9                        1
# 2011                            69                42                       26
# 2015                           303               273                      257
# 2009                            49                35                       21
# 2004                             0                 0                        0
# 1998                             0                 0                        0
# 2010                            47                31                       19
# 2016                           233               223                      230
# 2006                            16                 5                        1
# 2000                             0                 0                        0
# 2008                            19                 9                       11
# 2014                           229               239                      171
# 2005                             1                 2                        0
# 2001                             1                 2                        0
# 2003                             0                 0                        0
# 1999                             0                 0                        0
# 1997                             0                 0                        0
# 2017                             0                 2                        0
#
#              GenreIsEarlyAccess_count  GenreIsFreeToPlay_count  \
# ReleaseDate
# 2012                                1                       27
# 2013                               17                       27
# 2007                                0                        1
# 2011                                0                       12
# 2015                              143                      169
# 2009                                0                        2
# 2004                                0                        0
# 1998                                0                        0
# 2010                                0                        1
# 2016                              155                      154
# 2006                                0                        0
# 2000                                0                        0
# 2008                                0                        1
# 2014                               75                       79
# 2005                                0                        0
# 2001                                0                        0
# 2003                                0                        0
# 1999                                0                        0
# 1997                                0                        0
# 2017                                2                        0
#
#              GenreIsSports_count  GenreIsRacing_count  \
# ReleaseDate
# 2012                           9                   13
# 2013                          17                   19
# 2007                           0                    3
# 2011                           6                   12
# 2015                          51                   44
# 2009                           5                    7
# 2004                           0                    0
# 1998                           0                    0
# 2010                           4                    7
# 2016                          59                   42
# 2006                           0                    5
# 2000                           0                    0
# 2008                           1                    9
# 2014                          35                   48
# 2005                           0                    0
# 2001                           0                    0
# 2003                           0                    0
# 1999                           0                    0
# 1997                           0                    1
# 2017                           0                    0
#
#              GenreIsMassivelyMultiplayer_count  game_number
# ReleaseDate
# 2012                                        20          318
# 2013                                        15          421
# 2007                                         0           91
# 2011                                        10          237
# 2015                                        72         1242
# 2009                                         0          199
# 2004                                         0            8
# 1998                                         0            1
# 2010                                         1          192
# 2016                                        82         1067
# 2006                                         0           47
# 2000                                         0            2
# 2008                                         0          102
# 2014                                        45         1036
# 2005                                         0            4
# 2001                                         0            4
# 2003                                         0            2
# 1999                                         0            2
# 1997                                         0            1
# 2017                                         1            4

# %%
del year_rank['ResponseName']
del year_rank['score']
year_rank
# Out:
#              IsFree_count  GenreIsNonGame_count  GenreIsIndie_count  \
# ReleaseDate
# 2012                   31                     5                 155
# 2013                   35                     6                 224
# 2007                    5                     0                   8
# 2011                   16                     0                  83
# 2015                  189                    17                 878
# 2009                    7                     0                  46
# 2004                    1                     0                   0
# 1998                    0                     0                   0
# 2010                    3                     0                  54
# 2016                  195                    17                 727
# 2006                    2                     0                   5
# 2000                    0                     0                   0
# 2008                    3                     0                  14
# 2014                   89                    10                 669
# 2005                    1                     0                   1
# 2001                    2                     0                   1
# 2003                    0                     0                   1
# 1999                    0                     0                   0
# 1997                    0                     0                   1
# 2017                    0                     0                   3
#
#              GenreIsAction_count  GenreIsAdventure_count  GenreIsCasual_count  \
# ReleaseDate
# 2012                         175                      98                   45
# 2013                         227                     143                   58
# 2007                          56                       9                    9
# 2011                         122                      45                   35
# 2015                         582                     475                  288
# 2009                          89                      36                   23
# 2004                           8                       0                    0
# 1998                           1                       0                    0
# 2010                          93                      41                   30
# 2016                         481                     413                  280
# 2006                          22                       0                    3
# 2000                           2                       0                    0
# 2008                          54                      20                    7
# 2014                         499                     381                  229
# 2005                           1                       0                    0
# 2001                           3                       0                    0
# 2003                           2                       0                    1
# 1999                           2                       0                    0
# 1997                           1                       0                    0
# 2017                           4                       2                    0
#
#              GenreIsStrategy_count  GenreIsRPG_count  GenreIsSimulation_count  \
# ReleaseDate
# 2012                            76                61                       33
# 2013                           102                83                       73
# 2007                            21                 9                        1
# 2011                            69                42                       26
# 2015                           303               273                      257
# 2009                            49                35                       21
# 2004                             0                 0                        0
# 1998                             0                 0                        0
# 2010                            47                31                       19
# 2016                           233               223                      230
# 2006                            16                 5                        1
# 2000                             0                 0                        0
# 2008                            19                 9                       11
# 2014                           229               239                      171
# 2005                             1                 2                        0
# 2001                             1                 2                        0
# 2003                             0                 0                        0
# 1999                             0                 0                        0
# 1997                             0                 0                        0
# 2017                             0                 2                        0
#
#              GenreIsEarlyAccess_count  GenreIsFreeToPlay_count  \
# ReleaseDate
# 2012                                1                       27
# 2013                               17                       27
# 2007                                0                        1
# 2011                                0                       12
# 2015                              143                      169
# 2009                                0                        2
# 2004                                0                        0
# 1998                                0                        0
# 2010                                0                        1
# 2016                              155                      154
# 2006                                0                        0
# 2000                                0                        0
# 2008                                0                        1
# 2014                               75                       79
# 2005                                0                        0
# 2001                                0                        0
# 2003                                0                        0
# 1999                                0                        0
# 1997                                0                        0
# 2017                                2                        0
#
#              GenreIsSports_count  GenreIsRacing_count  \
# ReleaseDate
# 2012                           9                   13
# 2013                          17                   19
# 2007                           0                    3
# 2011                           6                   12
# 2015                          51                   44
# 2009                           5                    7
# 2004                           0                    0
# 1998                           0                    0
# 2010                           4                    7
# 2016                          59                   42
# 2006                           0                    5
# 2000                           0                    0
# 2008                           1                    9
# 2014                          35                   48
# 2005                           0                    0
# 2001                           0                    0
# 2003                           0                    0
# 1999                           0                    0
# 1997                           0                    1
# 2017                           0                    0
#
#              GenreIsMassivelyMultiplayer_count  game_number
# ReleaseDate
# 2012                                        20          318
# 2013                                        15          421
# 2007                                         0           91
# 2011                                        10          237
# 2015                                        72         1242
# 2009                                         0          199
# 2004                                         0            8
# 1998                                         0            1
# 2010                                         1          192
# 2016                                        82         1067
# 2006                                         0           47
# 2000                                         0            2
# 2008                                         0          102
# 2014                                        45         1036
# 2005                                         0            4
# 2001                                         0            4
# 2003                                         0            2
# 1999                                         0            2
# 1997                                         0            1
# 2017                                         1            4

# %%
total_index = year_rank
del total_index['IsFree_count']
del total_index['game_number']
total_index
# Out:
#              GenreIsNonGame_count  GenreIsIndie_count  GenreIsAction_count  \
# ReleaseDate
# 2012                            5                 155                  175
# 2013                            6                 224                  227
# 2007                            0                   8                   56
# 2011                            0                  83                  122
# 2015                           17                 878                  582
# 2009                            0                  46                   89
# 2004                            0                   0                    8
# 1998                            0                   0                    1
# 2010                            0                  54                   93
# 2016                           17                 727                  481
# 2006                            0                   5                   22
# 2000                            0                   0                    2
# 2008                            0                  14                   54
# 2014                           10                 669                  499
# 2005                            0                   1                    1
# 2001                            0                   1                    3
# 2003                            0                   1                    2
# 1999                            0                   0                    2
# 1997                            0                   1                    1
# 2017                            0                   3                    4
#
#              GenreIsAdventure_count  GenreIsCasual_count  \
# ReleaseDate
# 2012                             98                   45
# 2013                            143                   58
# 2007                              9                    9
# 2011                             45                   35
# 2015                            475                  288
# 2009                             36                   23
# 2004                              0                    0
# 1998                              0                    0
# 2010                             41                   30
# 2016                            413                  280
# 2006                              0                    3
# 2000                              0                    0
# 2008                             20                    7
# 2014                            381                  229
# 2005                              0                    0
# 2001                              0                    0
# 2003                              0                    1
# 1999                              0                    0
# 1997                              0                    0
# 2017                              2                    0
#
#              GenreIsStrategy_count  GenreIsRPG_count  GenreIsSimulation_count  \
# ReleaseDate
# 2012                            76                61                       33
# 2013                           102                83                       73
# 2007                            21                 9                        1
# 2011                            69                42                       26
# 2015                           303               273                      257
# 2009                            49                35                       21
# 2004                             0                 0                        0
# 1998                             0                 0                        0
# 2010                            47                31                       19
# 2016                           233               223                      230
# 2006                            16                 5                        1
# 2000                             0                 0                        0
# 2008                            19                 9                       11
# 2014                           229               239                      171
# 2005                             1                 2                        0
# 2001                             1                 2                        0
# 2003                             0                 0                        0
# 1999                             0                 0                        0
# 1997                             0                 0                        0
# 2017                             0                 2                        0
#
#              GenreIsEarlyAccess_count  GenreIsFreeToPlay_count  \
# ReleaseDate
# 2012                                1                       27
# 2013                               17                       27
# 2007                                0                        1
# 2011                                0                       12
# 2015                              143                      169
# 2009                                0                        2
# 2004                                0                        0
# 1998                                0                        0
# 2010                                0                        1
# 2016                              155                      154
# 2006                                0                        0
# 2000                                0                        0
# 2008                                0                        1
# 2014                               75                       79
# 2005                                0                        0
# 2001                                0                        0
# 2003                                0                        0
# 1999                                0                        0
# 1997                                0                        0
# 2017                                2                        0
#
#              GenreIsSports_count  GenreIsRacing_count  \
# ReleaseDate
# 2012                           9                   13
# 2013                          17                   19
# 2007                           0                    3
# 2011                           6                   12
# 2015                          51                   44
# 2009                           5                    7
# 2004                           0                    0
# 1998                           0                    0
# 2010                           4                    7
# 2016                          59                   42
# 2006                           0                    5
# 2000                           0                    0
# 2008                           1                    9
# 2014                          35                   48
# 2005                           0                    0
# 2001                           0                    0
# 2003                           0                    0
# 1999                           0                    0
# 1997                           0                    1
# 2017                           0                    0
#
#              GenreIsMassivelyMultiplayer_count
# ReleaseDate
# 2012                                        20
# 2013                                        15
# 2007                                         0
# 2011                                        10
# 2015                                        72
# 2009                                         0
# 2004                                         0
# 1998                                         0
# 2010                                         1
# 2016                                        82
# 2006                                         0
# 2000                                         0
# 2008                                         0
# 2014                                        45
# 2005                                         0
# 2001                                         0
# 2003                                         0
# 1999                                         0
# 1997                                         0
# 2017                                         1

# %%
total_index['ReleaseDate'] = [
    2012,
    2013,
    2007,
    2011,
    2015,
    2009,
    2004,
    1998,
    2012,
    2016,
    2006,
    2000,
    2008,
    2014,
    2005,
    2001,
    2003,
    1999,
    1997,
    2017
]

# %%
total_index.drop('ReleaseDate',axis=1).sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(5,4)
year_rank[0:1].sum().plot(kind='bar',ax=ax[0,0])
year_rank[1:2].sum().plot(kind='bar',ax=ax[0,1])
year_rank[2:3].sum().plot(kind='bar',ax=ax[0,2])
year_rank[3:4].sum().plot(kind='bar',ax=ax[0,3])
year_rank[4:5].sum().plot(kind='bar',ax=ax[1,0])
year_rank[5:6].sum().plot(kind='bar',ax=ax[1,1])
year_rank[6:7].sum().plot(kind='bar',ax=ax[1,2])
year_rank[7:8].sum().plot(kind='bar',ax=ax[1,3])
year_rank[8:9].sum().plot(kind='bar',ax=ax[2,0])
year_rank[9:10].sum().plot(kind='bar',ax=ax[2,1])
year_rank[10:11].sum().plot(kind='bar',ax=ax[2,2])
year_rank[11:12].sum().plot(kind='bar',ax=ax[2,3])
year_rank[12:13].sum().plot(kind='bar',ax=ax[3,0])
year_rank[13:14].sum().plot(kind='bar',ax=ax[3,1])
year_rank[14:15].sum().plot(kind='bar',ax=ax[3,2])
year_rank[15:16].sum().plot(kind='bar',ax=ax[3,3])
year_rank[16:17].sum().plot(kind='bar',ax=ax[4,0])
year_rank[17:18].sum().plot(kind='bar',ax=ax[4,1])
year_rank[18:19].sum().plot(kind='bar',ax=ax[4,2])
year_rank[19:20].sum().plot(kind='bar',ax=ax[4,3])
ax[0,0].set_xlabel('2012')
ax[0,1].set_xlabel('2013')
ax[0,2].set_xlabel('2007')
ax[0,3].set_xlabel('2011')
ax[1,0].set_xlabel('2015')
ax[1,1].set_xlabel('2009')
ax[1,2].set_xlabel('2004')
ax[1,3].set_xlabel('1998')
ax[2,0].set_xlabel('2010')
ax[2,1].set_xlabel('2016')
ax[2,2].set_xlabel('2006')
ax[2,3].set_xlabel('2000')
ax[3,0].set_xlabel('2008')
ax[3,1].set_xlabel('2014')
ax[3,2].set_xlabel('2005')
ax[3,3].set_xlabel('2001')
ax[4,0].set_xlabel('2003')
ax[4,1].set_xlabel('1999')
ax[4,2].set_xlabel('1997')
ax[4,3].set_xlabel('2017')
# Out:
# Text(0.5, 0, '2017')

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsNonGame_count)
plt.ylabel('GenreIsNonGame_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsIndie_count)
plt.ylabel('GenreIsIndie_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsAction_count)
plt.ylabel('GenreIsAction_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsAdventure_count)
plt.ylabel('GenreIsAdventure_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsCasual_count)
plt.ylabel('GenreIsCasual_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsStrategy_count)
plt.ylabel('GenreIsStrategy_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsRPG_count)
plt.ylabel('GenreIsRPG_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsSimulation_count)
plt.ylabel('GenreIsSimulation_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsEarlyAccess_count)
plt.ylabel('GenreIsEarlyAccess_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsFreeToPlay_count)
plt.ylabel('GenreIsFreeToPlay_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsSports_count)
plt.ylabel('GenreIsSports_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsRacing_count)
plt.ylabel('GenreIsRacing_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()

# %%
plt.bar(year_rank.ReleaseDate,year_rank.GenreIsMassivelyMultiplayer_count)
plt.ylabel('GenreIsMassivelyMultiplayer_count')
plt.xticks(year_rank.ReleaseDate)
plt.xlabel('year')
plt.show()
